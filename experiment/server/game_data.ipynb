# %%
# %pylab inline
import networkx as nx
import pandas as pd
import numpy as np
import json
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
num_players = 8
control = True
n_neighbors = 3

if control:
    assert num_players % 2 == 0, "num_players must be even"
    num_treated = int(num_players / 2)
else:
    num_treated = num_players

game_data = dict()
players = [int(x) for x in range(num_players)]
game_data['treatmentSet'] = [int(i) for i in np.random.choice(players, num_treated, replace=False)]
game_data['controlSet'] = [int(i) for i in (set(players) - set(game_data["treatmentSet"]))]

game_data['treatment'] = [i in game_data['treatmentSet'] for i in range(num_players)]


g = nx.random_regular_graph(n_neighbors, num_treated)
nx.draw_networkx(g)
plt.box("off")
plt.xticks([])
plt.yticks([])

game_data
# Out:
# /anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):
# /anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:424: MatplotlibDeprecationWarning:
# Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warn_deprecated("2.2", "Passing one of 'on', 'true', 'off', 'false' as a "
# {'treatmentSet': [7, 4, 6, 5],
#  'controlSet': [0, 1, 2, 3],
#  'treatment': [False, False, False, False, True, True, True, True]}

# %%
# assign neighbors
neighbors = {}
for n in range(num_treated):
    neighbors[game_data["treatmentSet"][n]] = [game_data["treatmentSet"][nb] for nb in g[n]]
    if control:
        neighbors[game_data["controlSet"][n]] = [game_data["controlSet"][nb] for nb in g[n]]
game_data['neighbors'] = neighbors
game_data
# Out:
# {'treatmentSet': [7, 4, 6, 5],
#  'controlSet': [0, 1, 2, 3],
#  'treatment': [False, False, False, False, True, True, True, True],
#  'neighbors': {7: [4, 5, 6],
#   0: [1, 3, 2],
#   4: [6, 7, 5],
#   1: [2, 0, 3],
#   6: [4, 5, 7],
#   2: [1, 3, 0],
#   5: [4, 6, 7],
#   3: [1, 2, 0]}}

# %%
# use_columns = ['Loc 1', 'Loc 2', 'Area 1', 'Area 2', 'Male 1', 'Male 2 ', 'Male 3',
#        'Female 1', 'Female 2', 'Female 3', 'Occupation 1', 'Occupation 2',
#        'Occupation 3', 'Crime 1', 'Crime 2', 'Event', 'Date 1', 'Date 2',
#        'Clothing 1', 'Clothing 2', 'Valuable Object 1', 'Valuable Object 2',
#        'Tool 1', 'Tool 2']

use_columns = ['Loc 1', 'Male 1',
       'Female 1', 'Occupation 1', 'Event', 'Date 1',
       'Clothing 1', 'Valuable Object 1',
       'Tool 1']

# %%
clue_nodes = pd.read_excel("Clues.xlsx", sheet_name="Nodes", )
clue_nodes['Date 1'] = clue_nodes['Date 1'].dt.strftime('%B %d')
clue_nodes['Date 2'] = clue_nodes['Date 2'].dt.strftime('%B %d')

clue_edges = pd.read_excel("Clues.xlsx", sheet_name="Edges")
clue_edges = clue_edges.loc[pd.notnull(clue_edges.index)] # drop null rows
clue_edges = clue_edges[use_columns].loc[use_columns]

# %%
# identify the nodes that will reresent concepts in the treatment group's belief network
treatment_nodes = {}
for col in clue_nodes.columns:
    treatment_nodes[col] = np.random.choice(list(clue_nodes[col].dropna()), 1)[0]
#treatment_nodes

# %%
# many nodes will be used in control group, shuffle their order
ctrl_nodes = {}
for col in clue_nodes.columns:
    ctrl_nodes[col] = list(np.random.permutation(list(clue_nodes[col].dropna())))
#control_nodes

# %%
clues = dict()
treatment_clue_ids = [] # facilitates assigning clues
for i, (row, series) in enumerate(clue_edges.iterrows()):
    for j, (col, val) in enumerate(series.iteritems()):
        if i < j:
            # treatment condition
            treat_row_node = str(treatment_nodes[row])
            treat_col_node = str(treatment_nodes[col])
            treat_clue_content = val.replace('{2}',treat_row_node).replace('{1}', treat_col_node).capitalize()+'.'
            treat_clue_id = "treat_clue_%i_%i"%(i+1,j+1)
            clues[treat_clue_id] = {"id": treat_clue_id,
                              "nodes":[i+1, j+1],
                              "content":[treat_clue_content]}
            treatment_clue_ids.append(treat_clue_id)
            
            # treatment condition
            ctrl_row_node = str(ctrl_nodes[row].pop())
            ctrl_col_node = str(ctrl_nodes[col].pop())
            ctrl_clue_content = val.replace('{2}',ctrl_row_node).replace('{1}', ctrl_col_node).capitalize()+'.'
            ctrl_clue_id = "ctrl_clue_%i_%i"%(i+1,j+1)
            clues[ctrl_clue_id] = {"id": ctrl_clue_id,
                              "nodes":[i+1, j+1],
                              "content":[ctrl_clue_content]}
            

game_data['clues'] = clues
print(len(clues))
# Out:
# 72

# %%
clues
# Out:
# {'treat_clue_1_2': {'id': 'treat_clue_1_2',
#   'nodes': [1, 2],
#   'content': ['Brian was seen at the cinema.']},
#  'ctrl_clue_1_2': {'id': 'ctrl_clue_1_2',
#   'nodes': [1, 2],
#   'content': ['Andrew was seen at the grocery store.']},
#  'treat_clue_1_3': {'id': 'treat_clue_1_3',
#   'nodes': [1, 3],
#   'content': ['Susan was seen at the cinema.']},
#  'ctrl_clue_1_3': {'id': 'ctrl_clue_1_3',
#   'nodes': [1, 3],
#   'content': ['Lisa was seen at the casino.']},
#  'treat_clue_1_4': {'id': 'treat_clue_1_4',
#   'nodes': [1, 4],
#   'content': ['A janitor works near the cinema.']},
#  'ctrl_clue_1_4': {'id': 'ctrl_clue_1_4',
#   'nodes': [1, 4],
#   'content': ['A teacher works near the church.']},
#  'treat_clue_1_5': {'id': 'treat_clue_1_5',
#   'nodes': [1, 5],
#   'content': ['The award ceremony happened at the cinema.']},
#  'ctrl_clue_1_5': {'id': 'ctrl_clue_1_5',
#   'nodes': [1, 5],
#   'content': ['The lecture happened at the gym.']},
#  'treat_clue_1_6': {'id': 'treat_clue_1_6',
#   'nodes': [1, 6],
#   'content': ['The cinema was busy on may 12.']},
#  'ctrl_clue_1_6': {'id': 'ctrl_clue_1_6',
#   'nodes': [1, 6],
#   'content': ['The café was busy on july 12.']},
#  'treat_clue_1_7': {'id': 'treat_clue_1_7',
#   'nodes': [1, 7],
#   'content': ['A pair of work boots was found in the cinema.']},
#  'ctrl_clue_1_7': {'id': 'ctrl_clue_1_7',
#   'nodes': [1, 7],
#   'content': ['A blue hoodie was found in gas station.']},
#  'treat_clue_1_8': {'id': 'treat_clue_1_8',
#   'nodes': [1, 8],
#   'content': ['The evidence was at the cinema.']},
#  'ctrl_clue_1_8': {'id': 'ctrl_clue_1_8',
#   'nodes': [1, 8],
#   'content': ['The trophy was at the copy shop.']},
#  'treat_clue_1_9': {'id': 'treat_clue_1_9',
#   'nodes': [1, 9],
#   'content': ['A crowbar was found in the cinema.']},
#  'ctrl_clue_1_9': {'id': 'ctrl_clue_1_9',
#   'nodes': [1, 9],
#   'content': ['A tazer was found in town hall.']},
#  'treat_clue_2_3': {'id': 'treat_clue_2_3',
#   'nodes': [2, 3],
#   'content': ['Susan is friends with brian.']},
#  'ctrl_clue_2_3': {'id': 'ctrl_clue_2_3',
#   'nodes': [2, 3],
#   'content': ['Mary is friends with george.']},
#  'treat_clue_2_4': {'id': 'treat_clue_2_4',
#   'nodes': [2, 4],
#   'content': ['Brian works as a janitor.']},
#  'ctrl_clue_2_4': {'id': 'ctrl_clue_2_4',
#   'nodes': [2, 4],
#   'content': ['Christopher works as a locksmith.']},
#  'treat_clue_2_5': {'id': 'treat_clue_2_5',
#   'nodes': [2, 5],
#   'content': ['Brian attended the award ceremony.']},
#  'ctrl_clue_2_5': {'id': 'ctrl_clue_2_5',
#   'nodes': [2, 5],
#   'content': ['Thomas attended the trade summit.']},
#  'treat_clue_2_6': {'id': 'treat_clue_2_6',
#   'nodes': [2, 6],
#   'content': ['Brian did not go to work on may 12.']},
#  'ctrl_clue_2_6': {'id': 'ctrl_clue_2_6',
#   'nodes': [2, 6],
#   'content': ['Michael did not go to work on january 19.']},
#  'treat_clue_2_7': {'id': 'treat_clue_2_7',
#   'nodes': [2, 7],
#   'content': ['Brian owns a a pair of work boots.']},
#  'ctrl_clue_2_7': {'id': 'ctrl_clue_2_7',
#   'nodes': [2, 7],
#   'content': ['Brian owns a a spotted bowtie.']},
#  'treat_clue_2_8': {'id': 'treat_clue_2_8',
#   'nodes': [2, 8],
#   'content': ['Brian had been to see the evidence.']},
#  'ctrl_clue_2_8': {'id': 'ctrl_clue_2_8',
#   'nodes': [2, 8],
#   'content': ['Richard had been to see the necklace.']},
#  'treat_clue_2_9': {'id': 'treat_clue_2_9',
#   'nodes': [2, 9],
#   'content': ['Brian had recently purchased a crowbar.']},
#  'ctrl_clue_2_9': {'id': 'ctrl_clue_2_9',
#   'nodes': [2, 9],
#   'content': ['Anthony had recently purchased a claw hammer.']},
#  'treat_clue_3_4': {'id': 'treat_clue_3_4',
#   'nodes': [3, 4],
#   'content': ['Susan works as a janitor.']},
#  'ctrl_clue_3_4': {'id': 'ctrl_clue_3_4',
#   'nodes': [3, 4],
#   'content': ['Karen works as a secretary.']},
#  'treat_clue_3_5': {'id': 'treat_clue_3_5',
#   'nodes': [3, 5],
#   'content': ['Susan attended the award ceremony.']},
#  'ctrl_clue_3_5': {'id': 'ctrl_clue_3_5',
#   'nodes': [3, 5],
#   'content': ['Sandra attended the food festival.']},
#  'treat_clue_3_6': {'id': 'treat_clue_3_6',
#   'nodes': [3, 6],
#   'content': ['Susan did not go to work on may 12.']},
#  'ctrl_clue_3_6': {'id': 'ctrl_clue_3_6',
#   'nodes': [3, 6],
#   'content': ['Betty did not go to work on june 17.']},
#  'treat_clue_3_7': {'id': 'treat_clue_3_7',
#   'nodes': [3, 7],
#   'content': ['Susan owns a a pair of work boots.']},
#  'ctrl_clue_3_7': {'id': 'ctrl_clue_3_7',
#   'nodes': [3, 7],
#   'content': ['Jessica owns a a hazmat suit.']},
#  'treat_clue_3_8': {'id': 'treat_clue_3_8',
#   'nodes': [3, 8],
#   'content': ['Susan had been to see the evidence.']},
#  'ctrl_clue_3_8': {'id': 'ctrl_clue_3_8',
#   'nodes': [3, 8],
#   'content': ['Michelle had been to see the prototype.']},
#  'treat_clue_3_9': {'id': 'treat_clue_3_9',
#   'nodes': [3, 9],
#   'content': ['Susan had recently purchased a crowbar.']},
#  'ctrl_clue_3_9': {'id': 'ctrl_clue_3_9',
#   'nodes': [3, 9],
#   'content': ['Kimberly had recently purchased a chain.']},
#  'treat_clue_4_5': {'id': 'treat_clue_4_5',
#   'nodes': [4, 5],
#   'content': ['A janitor attended the award ceremony.']},
#  'ctrl_clue_4_5': {'id': 'ctrl_clue_4_5',
#   'nodes': [4, 5],
#   'content': ['A truck driver attended the contest.']},
#  'treat_clue_4_6': {'id': 'treat_clue_4_6',
#   'nodes': [4, 6],
#   'content': ['A janitor did not go to work on may 12.']},
#  'ctrl_clue_4_6': {'id': 'ctrl_clue_4_6',
#   'nodes': [4, 6],
#   'content': ['A farmer did not go to work on march 26.']},
#  'treat_clue_4_7': {'id': 'treat_clue_4_7',
#   'nodes': [4, 7],
#   'content': ['A janitor was seen wearing a pair of work boots.']},
#  'ctrl_clue_4_7': {'id': 'ctrl_clue_4_7',
#   'nodes': [4, 7],
#   'content': ['A soldier was seen wearing a pair of ripped jeans.']},
#  'treat_clue_4_8': {'id': 'treat_clue_4_8',
#   'nodes': [4, 8],
#   'content': ['A janitor had been to see the evidence.']},
#  'ctrl_clue_4_8': {'id': 'ctrl_clue_4_8',
#   'nodes': [4, 8],
#   'content': ['A doctor had been to see the credit cards.']},
#  'treat_clue_4_9': {'id': 'treat_clue_4_9',
#   'nodes': [4, 9],
#   'content': ['A janitor has access to a crowbar.']},
#  'ctrl_clue_4_9': {'id': 'ctrl_clue_4_9',
#   'nodes': [4, 9],
#   'content': ['An architect has access to a knife.']},
#  'treat_clue_5_6': {'id': 'treat_clue_5_6',
#   'nodes': [5, 6],
#   'content': ['The award ceremony happened on may 12.']},
#  'ctrl_clue_5_6': {'id': 'ctrl_clue_5_6',
#   'nodes': [5, 6],
#   'content': ['The dance happened on july 23.']},
#  'treat_clue_5_7': {'id': 'treat_clue_5_7',
#   'nodes': [5, 7],
#   'content': ['A pair of work boots was at the award ceremony.']},
#  'ctrl_clue_5_7': {'id': 'ctrl_clue_5_7',
#   'nodes': [5, 7],
#   'content': ['A hardhat was at the concert.']},
#  'treat_clue_5_8': {'id': 'treat_clue_5_8',
#   'nodes': [5, 8],
#   'content': ['The evidence was at the award ceremony.']},
#  'ctrl_clue_5_8': {'id': 'ctrl_clue_5_8',
#   'nodes': [5, 8],
#   'content': ['The state secrets was at the party.']},
#  'treat_clue_5_9': {'id': 'treat_clue_5_9',
#   'nodes': [5, 9],
#   'content': ['A crowbar was found at the award ceremony.']},
#  'ctrl_clue_5_9': {'id': 'ctrl_clue_5_9',
#   'nodes': [5, 9],
#   'content': ['A set of lockpicks was found at the yard sale.']},
#  'treat_clue_6_7': {'id': 'treat_clue_6_7',
#   'nodes': [6, 7],
#   'content': ['A pair of work boots was found on may 12.']},
#  'ctrl_clue_6_7': {'id': 'ctrl_clue_6_7',
#   'nodes': [6, 7],
#   'content': ['A baseball cap was found on august 22.']},
#  'treat_clue_6_8': {'id': 'treat_clue_6_8',
#   'nodes': [6, 8],
#   'content': ['The evidence was lost on may 12.']},
#  'ctrl_clue_6_8': {'id': 'ctrl_clue_6_8',
#   'nodes': [6, 8],
#   'content': ['The crown was lost on november 02.']},
#  'treat_clue_6_9': {'id': 'treat_clue_6_9',
#   'nodes': [6, 9],
#   'content': ['A crowbar was found on may 12.']},
#  'ctrl_clue_6_9': {'id': 'ctrl_clue_6_9',
#   'nodes': [6, 9],
#   'content': ['A sledge hammer was found on november 08.']},
#  'treat_clue_7_8': {'id': 'treat_clue_7_8',
#   'nodes': [7, 8],
#   'content': ['The evidence was found with a pair of work boots.']},
#  'ctrl_clue_7_8': {'id': 'ctrl_clue_7_8',
#   'nodes': [7, 8],
#   'content': ['The recording was found with a silk handkercheif.']},
#  'treat_clue_7_9': {'id': 'treat_clue_7_9',
#   'nodes': [7, 9],
#   'content': ['A crowbar was found with a pair of work boots.']},
#  'ctrl_clue_7_9': {'id': 'ctrl_clue_7_9',
#   'nodes': [7, 9],
#   'content': ['A bolt cutter was found with a purple scarf.']},
#  'treat_clue_8_9': {'id': 'treat_clue_8_9',
#   'nodes': [8, 9],
#   'content': ['A crowbar was used to access the evidence.']},
#  'ctrl_clue_8_9': {'id': 'ctrl_clue_8_9',
#   'nodes': [8, 9],
#   'content': ['A chain saw was used to access the specimen.']}}

# %%
print('\n'.join([cl['content'][0] for cl in clues.values()][0::2]))
# Out:
# Brian was seen at the cinema.
# Susan was seen at the cinema.
# A janitor works near the cinema.
# The award ceremony happened at the cinema.
# The cinema was busy on may 12.
# A pair of work boots was found in the cinema.
# The evidence was at the cinema.
# A crowbar was found in the cinema.
# Susan is friends with brian.
# Brian works as a janitor.
# Brian attended the award ceremony.
# Brian did not go to work on may 12.
# Brian owns a a pair of work boots.
# Brian had been to see the evidence.
# Brian had recently purchased a crowbar.
# Susan works as a janitor.
# Susan attended the award ceremony.
# Susan did not go to work on may 12.
# Susan owns a a pair of work boots.
# Susan had been to see the evidence.
# Susan had recently purchased a crowbar.
# A janitor attended the award ceremony.
# A janitor did not go to work on may 12.
# A janitor was seen wearing a pair of work boots.
# A janitor had been to see the evidence.
# A janitor has access to a crowbar.
# The award ceremony happened on may 12.
# A pair of work boots was at the award ceremony.
# The evidence was at the award ceremony.
# A crowbar was found at the award ceremony.
# A pair of work boots was found on may 12.
# The evidence was lost on may 12.
# A crowbar was found on may 12.
# The evidence was found with a pair of work boots.
# A crowbar was found with a pair of work boots.
# A crowbar was used to access the evidence.

# %%
beliefs = {}
for n in range(num_treated):
    treat_beliefs = list(np.random.choice(treatment_clue_ids, 5, replace=False))
    beliefs[game_data["treatmentSet"][n]] = treat_beliefs

    if control:
        control_beliefs = [bf.replace('treat', 'ctrl') for bf in treat_beliefs]
        beliefs[game_data["controlSet"][n]] = control_beliefs        


    
game_data['beliefs'] = beliefs

# %%
game_data
# Out:
# {'treatmentSet': [0, 1, 2, 3],
#  'controlSet': [],
#  'treatment': [True, True, True, True],
#  'clues': {'treat_clue_1_2': {'id': 'treat_clue_1_2',
#    'nodes': [1, 2],
#    'content': ['John was seen at the gym.']},
#   'ctrl_clue_1_2': {'id': 'ctrl_clue_1_2',
#    'nodes': [1, 2],
#    'content': ['Brian was seen at the office.']},
#   'treat_clue_1_3': {'id': 'treat_clue_1_3',
#    'nodes': [1, 3],
#    'content': ['Sandra was seen at the gym.']},
#   'ctrl_clue_1_3': {'id': 'ctrl_clue_1_3',
#    'nodes': [1, 3],
#    'content': ['Lisa was seen at the library.']},
#   'treat_clue_1_4': {'id': 'treat_clue_1_4',
#    'nodes': [1, 4],
#    'content': ['A clockmaker works near the gym.']},
#   'ctrl_clue_1_4': {'id': 'ctrl_clue_1_4',
#    'nodes': [1, 4],
#    'content': ['A chef works near gas station.']},
#   'treat_clue_1_5': {'id': 'treat_clue_1_5',
#    'nodes': [1, 5],
#    'content': ['The convention happened at the gym.']},
#   'ctrl_clue_1_5': {'id': 'ctrl_clue_1_5',
#    'nodes': [1, 5],
#    'content': ['The food festival happened at the cinema.']},
#   'treat_clue_1_6': {'id': 'treat_clue_1_6',
#    'nodes': [1, 6],
#    'content': ['The gym was busy on february 18.']},
#   'ctrl_clue_1_6': {'id': 'ctrl_clue_1_6',
#    'nodes': [1, 6],
#    'content': ['The museum was busy on december 08.']},
#   'treat_clue_1_7': {'id': 'treat_clue_1_7',
#    'nodes': [1, 7],
#    'content': ['A pair of welding goggles was found in the gym.']},
#   'ctrl_clue_1_7': {'id': 'ctrl_clue_1_7',
#    'nodes': [1, 7],
#    'content': ['A pair of greasy overalls was found in the construction site.']},
#   'treat_clue_1_8': {'id': 'treat_clue_1_8',
#    'nodes': [1, 8],
#    'content': ['The relic was at the gym.']},
#   'ctrl_clue_1_8': {'id': 'ctrl_clue_1_8',
#    'nodes': [1, 8],
#    'content': ['The prototype was at the stadium.']},
#   'treat_clue_1_9': {'id': 'treat_clue_1_9',
#    'nodes': [1, 9],
#    'content': ['A rope was found in the gym.']},
#   'ctrl_clue_1_9': {'id': 'ctrl_clue_1_9',
#    'nodes': [1, 9],
#    'content': ["A road flare was found in the farmer's market."]},
#   'treat_clue_2_3': {'id': 'treat_clue_2_3',
#    'nodes': [2, 3],
#    'content': ['Sandra is friends with john.']},
#   'ctrl_clue_2_3': {'id': 'ctrl_clue_2_3',
#    'nodes': [2, 3],
#    'content': ['Linda is friends with george.']},
#   'treat_clue_2_4': {'id': 'treat_clue_2_4',
#    'nodes': [2, 4],
#    'content': ['John works as a clockmaker.']},
#   'ctrl_clue_2_4': {'id': 'ctrl_clue_2_4',
#    'nodes': [2, 4],
#    'content': ['Edward works as a cashier.']},
#   'treat_clue_2_5': {'id': 'treat_clue_2_5',
#    'nodes': [2, 5],
#    'content': ['John attended the convention.']},
#   'ctrl_clue_2_5': {'id': 'ctrl_clue_2_5',
#    'nodes': [2, 5],
#    'content': ['William attended the lecture.']},
#   'treat_clue_2_6': {'id': 'treat_clue_2_6',
#    'nodes': [2, 6],
#    'content': ['John did not go to work on february 18.']},
#   'ctrl_clue_2_6': {'id': 'ctrl_clue_2_6',
#    'nodes': [2, 6],
#    'content': ['James did not go to work on may 01.']},
#   'treat_clue_2_7': {'id': 'treat_clue_2_7',
#    'nodes': [2, 7],
#    'content': ['John owns a a pair of welding goggles.']},
#   'ctrl_clue_2_7': {'id': 'ctrl_clue_2_7',
#    'nodes': [2, 7],
#    'content': ['Thomas owns a a silk handkercheif.']},
#   'treat_clue_2_8': {'id': 'treat_clue_2_8',
#    'nodes': [2, 8],
#    'content': ['John had been to see the relic.']},
#   'ctrl_clue_2_8': {'id': 'ctrl_clue_2_8',
#    'nodes': [2, 8],
#    'content': ['John had been to see the cash.']},
#   'treat_clue_2_9': {'id': 'treat_clue_2_9',
#    'nodes': [2, 9],
#    'content': ['John had recently purchased a rope.']},
#   'ctrl_clue_2_9': {'id': 'ctrl_clue_2_9',
#    'nodes': [2, 9],
#    'content': ['Michael had recently purchased a hacksaw.']},
#   'treat_clue_3_4': {'id': 'treat_clue_3_4',
#    'nodes': [3, 4],
#    'content': ['Sandra works as a clockmaker.']},
#   'ctrl_clue_3_4': {'id': 'ctrl_clue_3_4',
#    'nodes': [3, 4],
#    'content': ['Susan works as an engineer.']},
#   'treat_clue_3_5': {'id': 'treat_clue_3_5',
#    'nodes': [3, 5],
#    'content': ['Sandra attended the convention.']},
#   'ctrl_clue_3_5': {'id': 'ctrl_clue_3_5',
#    'nodes': [3, 5],
#    'content': ['Carol attended the wine tasting.']},
#   'treat_clue_3_6': {'id': 'treat_clue_3_6',
#    'nodes': [3, 6],
#    'content': ['Sandra did not go to work on february 18.']},
#   'ctrl_clue_3_6': {'id': 'ctrl_clue_3_6',
#    'nodes': [3, 6],
#    'content': ['Amanda did not go to work on november 02.']},
#   'treat_clue_3_7': {'id': 'treat_clue_3_7',
#    'nodes': [3, 7],
#    'content': ['Sandra owns a a pair of welding goggles.']},
#   'ctrl_clue_3_7': {'id': 'ctrl_clue_3_7',
#    'nodes': [3, 7],
#    'content': ['Nancy owns a a spotted bowtie.']},
#   'treat_clue_3_8': {'id': 'treat_clue_3_8',
#    'nodes': [3, 8],
#    'content': ['Sandra had been to see the relic.']},
#   'ctrl_clue_3_8': {'id': 'ctrl_clue_3_8',
#    'nodes': [3, 8],
#    'content': ['Melissa had been to see the bracelet.']},
#   'treat_clue_3_9': {'id': 'treat_clue_3_9',
#    'nodes': [3, 9],
#    'content': ['Sandra had recently purchased a rope.']},
#   'ctrl_clue_3_9': {'id': 'ctrl_clue_3_9',
#    'nodes': [3, 9],
#    'content': ['Patricia had recently purchased a shovel.']},
#   'treat_clue_4_5': {'id': 'treat_clue_4_5',
#    'nodes': [4, 5],
#    'content': ['A clockmaker attended the convention.']},
#   'ctrl_clue_4_5': {'id': 'ctrl_clue_4_5',
#    'nodes': [4, 5],
#    'content': ['A banker attended the debate.']},
#   'treat_clue_4_6': {'id': 'treat_clue_4_6',
#    'nodes': [4, 6],
#    'content': ['A clockmaker did not go to work on february 18.']},
#   'ctrl_clue_4_6': {'id': 'ctrl_clue_4_6',
#    'nodes': [4, 6],
#    'content': ['A teacher did not go to work on august 22.']},
#   'treat_clue_4_7': {'id': 'treat_clue_4_7',
#    'nodes': [4, 7],
#    'content': ['A clockmaker was seen wearing a pair of welding goggles.']},
#   'ctrl_clue_4_7': {'id': 'ctrl_clue_4_7',
#    'nodes': [4, 7],
#    'content': ['A stunt double was seen wearing a tweed jacket.']},
#   'treat_clue_4_8': {'id': 'treat_clue_4_8',
#    'nodes': [4, 8],
#    'content': ['A clockmaker had been to see the relic.']},
#   'ctrl_clue_4_8': {'id': 'ctrl_clue_4_8',
#    'nodes': [4, 8],
#    'content': ['A masseuse had been to see the manuscript.']},
#   'treat_clue_4_9': {'id': 'treat_clue_4_9',
#    'nodes': [4, 9],
#    'content': ['A clockmaker has access to a rope.']},
#   'ctrl_clue_4_9': {'id': 'ctrl_clue_4_9',
#    'nodes': [4, 9],
#    'content': ['A manager has access to a ladder.']},
#   'treat_clue_5_6': {'id': 'treat_clue_5_6',
#    'nodes': [5, 6],
#    'content': ['The convention happened on february 18.']},
#   'ctrl_clue_5_6': {'id': 'ctrl_clue_5_6',
#    'nodes': [5, 6],
#    'content': ['The car show happened on february 24.']},
#   'treat_clue_5_7': {'id': 'treat_clue_5_7',
#    'nodes': [5, 7],
#    'content': ['A pair of welding goggles was at the convention.']},
#   'ctrl_clue_5_7': {'id': 'ctrl_clue_5_7',
#    'nodes': [5, 7],
#    'content': ['A pair of rain boots was at the graduation.']},
#   'treat_clue_5_8': {'id': 'treat_clue_5_8',
#    'nodes': [5, 8],
#    'content': ['The relic was at the convention.']},
#   'ctrl_clue_5_8': {'id': 'ctrl_clue_5_8',
#    'nodes': [5, 8],
#    'content': ['The blueprints was at the fair.']},
#   'treat_clue_5_9': {'id': 'treat_clue_5_9',
#    'nodes': [5, 9],
#    'content': ['A rope was found at the convention.']},
#   'ctrl_clue_5_9': {'id': 'ctrl_clue_5_9',
#    'nodes': [5, 9],
#    'content': ['A set of lockpicks was found at the baseball game.']},
#   'treat_clue_6_7': {'id': 'treat_clue_6_7',
#    'nodes': [6, 7],
#    'content': ['A pair of welding goggles was found on february 18.']},
#   'ctrl_clue_6_7': {'id': 'ctrl_clue_6_7',
#    'nodes': [6, 7],
#    'content': ['A blonde wig was found on july 17.']},
#   'treat_clue_6_8': {'id': 'treat_clue_6_8',
#    'nodes': [6, 8],
#    'content': ['The relic was lost on february 18.']},
#   'ctrl_clue_6_8': {'id': 'ctrl_clue_6_8',
#    'nodes': [6, 8],
#    'content': ['The painting was lost on june 06.']},
#   'treat_clue_6_9': {'id': 'treat_clue_6_9',
#    'nodes': [6, 9],
#    'content': ['A rope was found on february 18.']},
#   'ctrl_clue_6_9': {'id': 'ctrl_clue_6_9',
#    'nodes': [6, 9],
#    'content': ['A nail gun was found on march 31.']},
#   'treat_clue_7_8': {'id': 'treat_clue_7_8',
#    'nodes': [7, 8],
#    'content': ['The relic was found with a pair of welding goggles.']},
#   'ctrl_clue_7_8': {'id': 'ctrl_clue_7_8',
#    'nodes': [7, 8],
#    'content': ['The secret recipe was found with a set of scrubs.']},
#   'treat_clue_7_9': {'id': 'treat_clue_7_9',
#    'nodes': [7, 9],
#    'content': ['A rope was found with a pair of welding goggles.']},
#   'ctrl_clue_7_9': {'id': 'ctrl_clue_7_9',
#    'nodes': [7, 9],
#    'content': ['A crowbar was found with a surgical mask.']},
#   'treat_clue_8_9': {'id': 'treat_clue_8_9',
#    'nodes': [8, 9],
#    'content': ['A rope was used to access the relic.']},
#   'ctrl_clue_8_9': {'id': 'ctrl_clue_8_9',
#    'nodes': [8, 9],
#    'content': ['A wrench was used to access the treasure.']}},
#  'beliefs': {0: ['treat_clue_1_6',
#    'treat_clue_3_8',
#    'treat_clue_7_8',
#    'treat_clue_3_9',
#    'treat_clue_6_9'],
#   1: ['treat_clue_3_6',
#    'treat_clue_5_9',
#    'treat_clue_4_5',
#    'treat_clue_4_7',
#    'treat_clue_5_7'],
#   2: ['treat_clue_3_4',
#    'treat_clue_8_9',
#    'treat_clue_2_7',
#    'treat_clue_1_3',
#    'treat_clue_7_9'],
#   3: ['treat_clue_6_7',
#    'treat_clue_7_8',
#    'treat_clue_1_6',
#    'treat_clue_1_4',
#    'treat_clue_1_7']}}

# %%
with open("game_data_8_player_no_control.json", 'w') as f:
    f.write(json.dumps(game_data, indent=1))
