# %% [markdown]
# # Mediation Analysis

# %%
#install.packages("lavaan", dependencies=TRUE)
library(lavaan)
# Out:
# This is lavaan 0.6-6
#
# lavaan is BETA software! Please report any bugs.

# %%
working_dir = "../results-anonymized/pilot/"
game_factors = read.csv(paste(working_dir, "game_level_factors.csv", sep=""))
game_factors
# Out:
#   X                      n_shared_edges n_triangle
# 1 GT_5wifJzSKTJuDtQkzS_1  0.108601099    0.837267267
# 2 GT_acKghgvvb3kewvMd9_0 -0.020428987    0.955068306
# 3 GT_acKghgvvb3kewvMd9_1 -0.048037423   -0.212331368
# 4 GT_aufBQzkbCokRBX9js_0 -0.008959724    0.052902245
# 5 GT_aufBQzkbCokRBX9js_1 -0.080229210   -0.007329374
# 6 GT_bALDaKPEGyutrm8bn_0  0.023233790    0.972015023
# 7 GT_bALDaKPEGyutrm8bn_1 -0.092498556    0.277238818
# 8 GT_Bd3w7KBP8ZKKMBxhj_0  0.032200046    0.165216670
# 9 GT_Bd3w7KBP8ZKKMBxhj_1  0.068241028    0.579382700

# %%
game_outcomes = read.csv(paste(working_dir, "end_of_game_measurements.csv", sep=""))
game_outcomes
# Out:
#    X                      confidence consensus id
# 1  GT_Bd3w7KBP8ZKKMBxhj_0 53.40      55.15     Bd3w7KBP8ZKKMBxhj
# 2  GT_Bd3w7KBP8ZKKMBxhj_1 53.50      51.60     Bd3w7KBP8ZKKMBxhj
# 3  GT_xXvsHQvoQC4LsoyCi_0 43.35      42.70     xXvsHQvoQC4LsoyCi
# 4  GT_xXvsHQvoQC4LsoyCi_1 59.35      53.50     xXvsHQvoQC4LsoyCi
# 5  GT_5wifJzSKTJuDtQkzS_0 57.55      54.55     5wifJzSKTJuDtQkzS
# 6  GT_5wifJzSKTJuDtQkzS_1 52.35      57.10     5wifJzSKTJuDtQkzS
# 7  GT_acKghgvvb3kewvMd9_0 50.50      50.60     acKghgvvb3kewvMd9
# 8  GT_acKghgvvb3kewvMd9_1 58.30      54.45     acKghgvvb3kewvMd9
# 9  GT_nan_0                  NA         NA
# 10 GT_nan_1                  NA         NA
# 11 GT_hRLty7e6fGMsjgzJH_0 50.00      54.35     hRLty7e6fGMsjgzJH
# 12 GT_hRLty7e6fGMsjgzJH_1 48.85      53.20     hRLty7e6fGMsjgzJH
# 13 GT_nan_0                  NA         NA
# 14 GT_nan_1                  NA         NA
# 15 GT_bALDaKPEGyutrm8bn_0 45.30      42.15     bALDaKPEGyutrm8bn
# 16 GT_bALDaKPEGyutrm8bn_1 44.65      53.75     bALDaKPEGyutrm8bn
# 17 GT_kEHF9QnbLb3YtYfbj_0 45.90      48.60     kEHF9QnbLb3YtYfbj
# 18 GT_kEHF9QnbLb3YtYfbj_1 64.45      66.30     kEHF9QnbLb3YtYfbj
# 19 GT_aufBQzkbCokRBX9js_0 55.80      55.55     aufBQzkbCokRBX9js
# 20 GT_aufBQzkbCokRBX9js_1 55.75      50.20     aufBQzkbCokRBX9js
#    net.spoke.5..similarity net.spoke.95..similarity net.spoke.PC1
# 1  -0.18399680             0.315043648              0.205429659
# 2  -0.13734803             0.375999508              0.316695954
# 3  -0.17118327             0.196307721              0.087011352
# 4  -0.15197388             0.178643192              0.114432875
# 5  -0.20471261             0.315690224              0.240604278
# 6  -0.17312963             0.297532102              0.213024379
# 7  -0.13767998             0.144667522              0.115307468
# 8  -0.12719578             0.008823933              0.056882950
# 9           NA                      NA                       NA
# 10          NA                      NA                       NA
# 11 -0.01124797             0.040324653              0.038649254
# 12 -0.03089946             0.096732855              0.040877343
# 13          NA                      NA                       NA
# 14          NA                      NA                       NA
# 15  0.02520484             0.076482961              0.049988163
# 16 -0.12887903             0.131131871              0.096366949
# 17 -0.13117467             0.224607290              0.157001253
# 18 -0.05462963             0.472547383              0.212115556
# 19 -0.03815374             0.131066130              0.000352079
# 20 -0.04649977             0.068330889              0.067472898
#    spoke.5..similarity spoke.95..similarity spoke.PC1 survey.5..similarity
# 1  -0.41833001         0.8068320            0.3826353 -0.7253466
# 2  -0.34090534         0.8964215            0.5055998 -0.5532093
# 3  -0.29351850         0.7174301            0.3427743 -0.4923093
# 4  -0.33469060         0.7163280            0.3011368 -0.5495729
# 5  -0.31352722         0.9004225            0.4224825 -0.6216857
# 6  -0.43033148         0.7830465            0.3971251 -0.5391928
# 7  -0.31875420         0.6708204            0.3747241 -0.4858827
# 8  -0.13853444         0.6420708            0.2499152 -0.3518347
# 9           NA                NA                   NA         NA
# 10          NA                NA                   NA         NA
# 11 -0.15789474         0.6900656            0.2529498 -0.2099454
# 12 -0.21602469         0.6517949            0.2532558 -0.4895671
# 13          NA                NA                   NA         NA
# 14          NA                NA                   NA         NA
# 15 -0.14907120         0.6123724            0.2338279 -0.5275344
# 16 -0.36948216         0.6185529            0.2846107 -0.5635352
# 17 -0.29452542         0.8038941            0.4072050 -0.4907663
# 18 -0.28867513         1.0000000            0.4020640 -0.5778600
# 19  0.03142015         0.8035714            0.2921632 -0.2634235
# 20 -0.16878989         0.6058713            0.2563659 -0.3917069
#    survey.95..similarity survey.PC1 t network
# 1  0.7477892             0.3596869  0 1
# 2  0.8737833             0.4884265  1 1
# 3  0.5750303             0.2791860  0 0
# 4  0.7466679             0.4175219  1 0
# 5  0.7234857             0.4402810  0 1
# 6  0.6865643             0.3542928  1 1
# 7  0.7394582             0.4196030  0 0
# 8  0.6901219             0.3119373  1 0
# 9         NA                    NA  0 1
# 10        NA                    NA  1 1
# 11 0.7802773             0.2679061  0 0
# 12 0.6502811             0.2652249  1 0
# 13        NA                    NA  0 1
# 14        NA                    NA  1 1
# 15 0.7271513             0.3697807  0 0
# 16 0.6276550             0.3568511  1 0
# 17 0.7164797             0.3048156  0 1
# 18 0.8041508             0.4285799  1 1
# 19 0.7333750             0.2539695  0 0
# 20 0.7052521             0.3604069  1 0

# %%
df = merge(game_factors, game_outcomes)
df
# Out:
#   X                      n_shared_edges n_triangle   confidence consensus
# 1 GT_5wifJzSKTJuDtQkzS_1  0.108601099    0.837267267 52.35      57.10
# 2 GT_acKghgvvb3kewvMd9_0 -0.020428987    0.955068306 50.50      50.60
# 3 GT_acKghgvvb3kewvMd9_1 -0.048037423   -0.212331368 58.30      54.45
# 4 GT_aufBQzkbCokRBX9js_0 -0.008959724    0.052902245 55.80      55.55
# 5 GT_aufBQzkbCokRBX9js_1 -0.080229210   -0.007329374 55.75      50.20
# 6 GT_bALDaKPEGyutrm8bn_0  0.023233790    0.972015023 45.30      42.15
# 7 GT_bALDaKPEGyutrm8bn_1 -0.092498556    0.277238818 44.65      53.75
# 8 GT_Bd3w7KBP8ZKKMBxhj_0  0.032200046    0.165216670 53.40      55.15
# 9 GT_Bd3w7KBP8ZKKMBxhj_1  0.068241028    0.579382700 53.50      51.60
#   id                net.spoke.5..similarity net.spoke.95..similarity
# 1 5wifJzSKTJuDtQkzS -0.17312963             0.297532102
# 2 acKghgvvb3kewvMd9 -0.13767998             0.144667522
# 3 acKghgvvb3kewvMd9 -0.12719578             0.008823933
# 4 aufBQzkbCokRBX9js -0.03815374             0.131066130
# 5 aufBQzkbCokRBX9js -0.04649977             0.068330889
# 6 bALDaKPEGyutrm8bn  0.02520484             0.076482961
# 7 bALDaKPEGyutrm8bn -0.12887903             0.131131871
# 8 Bd3w7KBP8ZKKMBxhj -0.18399680             0.315043648
# 9 Bd3w7KBP8ZKKMBxhj -0.13734803             0.375999508
#   net.spoke.PC1 spoke.5..similarity spoke.95..similarity spoke.PC1
# 1 0.213024379   -0.43033148         0.7830465            0.3971251
# 2 0.115307468   -0.31875420         0.6708204            0.3747241
# 3 0.056882950   -0.13853444         0.6420708            0.2499152
# 4 0.000352079    0.03142015         0.8035714            0.2921632
# 5 0.067472898   -0.16878989         0.6058713            0.2563659
# 6 0.049988163   -0.14907120         0.6123724            0.2338279
# 7 0.096366949   -0.36948216         0.6185529            0.2846107
# 8 0.205429659   -0.41833001         0.8068320            0.3826353
# 9 0.316695954   -0.34090534         0.8964215            0.5055998
#   survey.5..similarity survey.95..similarity survey.PC1 t network
# 1 -0.5391928           0.6865643             0.3542928  1 1
# 2 -0.4858827           0.7394582             0.4196030  0 0
# 3 -0.3518347           0.6901219             0.3119373  1 0
# 4 -0.2634235           0.7333750             0.2539695  0 0
# 5 -0.3917069           0.7052521             0.3604069  1 0
# 6 -0.5275344           0.7271513             0.3697807  0 0
# 7 -0.5635352           0.6276550             0.3568511  1 0
# 8 -0.7253466           0.7477892             0.3596869  0 1
# 9 -0.5532093           0.8737833             0.4884265  1 1

# %%
set.seed(1234)
X <- rnorm(100)
M <- 0.5*X + rnorm(100)
Y <- 0.7*M + rnorm(100)
Data <- data.frame(X = X, Y = Y, M = M)
model <- ' # mediator
             n_shared_edges ~ a*n_triangle

           # effect on PC1
             net.spoke.PC1 ~ PC1.spoke.c*n_triangle  # direct effect
             net.spoke.PC1 ~ PC1.spoke.b*n_shared_edges  # effect of mediator
             net.spoke.PC1 ~ PC1.spoke.n*network  # effect of network structure

             PC1.spoke.indirect := (a*PC1.spoke.b)
             PC1.spoke.total := PC1.spoke.c + (a*PC1.spoke.b)

             survey.PC1 ~ PC1.survey.c*n_triangle
             survey.PC1 ~ PC1.survey.b*n_shared_edges 
             survey.PC1 ~ PC1.survey.n*network

             PC1.survey.indirect := (a*PC1.survey.b)
             #PC1.survey.total := PC1.survey.c + (a*PC1.survey.b)
             PC1.survey.total := PC1.survey.c + PC1.survey.indirect
             PC1.survey.mediationFrac := (PC1.survey.indirect / PC1.survey.total)
             
             
           # effect on 5% similarity
             net.spoke.5..similarity ~ S5.spoke.c*n_triangle 
             net.spoke.5..similarity ~ S5.spoke.b*n_shared_edges 
             net.spoke.5..similarity ~ S5.spoke.n*network

             S5.spoke.indirect := (a*S5.spoke.b)
             S5.spoke.total := S5.spoke.c + (a*S5.spoke.b)

             survey.5..similarity ~ S5.survey.c*n_triangle
             survey.5..similarity ~ S5.survey.b*n_shared_edges 
             survey.5..similarity ~ S5.survey.n*network

             S5.survey.indirect := (a*S5.spoke.b)
             S5.survey.total := S5.spoke.c + (a*S5.spoke.b)

           # effect on 95% similarity
             net.spoke.95..similarity ~ S95.spoke.c*n_triangle 
             net.spoke.95..similarity ~ S95.spoke.b*n_shared_edges 
             net.spoke.95..similarity ~ S95.spoke.n*network

             S95.spoke.indirect := (a*S95.spoke.b)
             S95.spoke.total := S95.spoke.c + (a*S95.spoke.b)

             survey.95..similarity ~ S95.survey.c*n_triangle
             survey.95..similarity ~ S95.survey.b*n_shared_edges 
             survey.95..similarity ~ S95.survey.n*network

             S95.survey.indirect := (a*S95.spoke.b)
             S95.survey.total := S95.spoke.c + (a*S95.spoke.b)
        

         '
fit <- sem(model, data = df)
summary(fit)
# Out:
# Warning message in lav_model_estimate(lavmodel = lavmodel, lavpartable = lavpartable, :
# “lavaan WARNING: the optimizer warns that a solution has NOT been found!”
# lavaan 0.6-6 did NOT end normally after 414 iterations
# ** WARNING ** Estimates below are most likely unreliable
#
#   Estimator                                         ML
#   Optimization method                           NLMINB
#   Number of free parameters                         41
#
#   Number of observations                             9
#
# Model Test User Model:
#
#   Test statistic                                    NA
#   Degrees of freedom                                NA
#
# Parameter Estimates:
#
#   Standard errors                             Standard
#   Information                                 Expected
#   Information saturated (h1) model          Structured
#
# Regressions:
#                              Estimate  Std.Err  z-value  P(>|z|)
#   n_shared_edges ~
#     n          (a)              0.095       NA
#   net.spoke.PC1 ~
#     n  (PC1.spk.c)              0.025       NA
#     n  (PC1.spk.b)             -0.112       NA
#     n  (PC1.spk.n)              0.177       NA
#   survey.PC1 ~
#     n (PC1.srvy.c)              0.092       NA
#     n (PC1.srvy.b)             -0.570       NA
#     n (PC1.srvy.n)              0.091       NA
#   net.spoke.5..similarity ~
#     n   (S5.spk.c)              0.002       NA
#     n   (S5.spk.b)              0.213       NA
#     n   (S5.spk.n)             -0.116       NA
#   survey.5..similarity ~
#     n  (S5.srvy.c)             -0.068       NA
#     n  (S5.srvy.b)              0.255       NA
#     n  (S5.srvy.n)             -0.175       NA
#   net.spoke.95..similarity ~
#     n  (S95.spk.c)              0.057       NA
#     n  (S95.spk.b)             -0.420       NA
#     n  (S95.spk.n)              0.263       NA
#   survey.95..similarity ~
#     n (S95.srvy.c)             -0.012       NA
#     n (S95.srvy.b)              0.432       NA
#     n (S95.srvy.n)              0.016       NA
#
# Covariances:
#                               Estimate  Std.Err  z-value  P(>|z|)
#  .net.spoke.PC1 ~~
#    .survey.PC1                   0.001       NA
#    .nt.spk.5..smlr              -0.001       NA
#    .srvy.5..smlrty              -0.000       NA
#    .nt.spk.95..sml               0.000       NA
#    .srvy.95..smlrt               0.001       NA
#  .survey.PC1 ~~
#    .nt.spk.5..smlr               0.000       NA
#    .srvy.5..smlrty               0.000       NA
#    .nt.spk.95..sml               0.000       NA
#    .srvy.95..smlrt               0.002       NA
#  .net.spoke.5..similarity ~~
#    .srvy.5..smlrty              -0.000       NA
#    .nt.spk.95..sml              -0.000       NA
#    .srvy.95..smlrt               0.001       NA
#  .survey.5..similarity ~~
#    .nt.spk.95..sml               0.001       NA
#    .srvy.95..smlrt               0.002       NA
#  .net.spoke.95..similarity ~~
#    .srvy.95..smlrt               0.001       NA
#
# Variances:
#                    Estimate  Std.Err  z-value  P(>|z|)
#    .n_shared_edges    0.003       NA
#    .net.spoke.PC1     0.002       NA
#    .survey.PC1        0.002       NA
#    .nt.spk.5..smlr    0.003       NA
#    .srvy.5..smlrty    0.008       NA
#    .nt.spk.95..sml    0.002       NA
#    .srvy.95..smlrt    0.003       NA
#
# Defined Parameters:
#                    Estimate  Std.Err  z-value  P(>|z|)
#     PC1.spok.ndrct   -0.011
#     PC1.spoke.totl    0.014
#     PC1.srvy.ndrct   -0.054
#     PC1.survey.ttl    0.038
#     PC1.srvy.mdtnF   -1.405
#     S5.spoke.ndrct    0.020
#     S5.spoke.total    0.022
#     S5.survy.ndrct    0.020
#     S5.survey.totl    0.022
#     S95.spok.ndrct   -0.040
#     S95.spoke.totl    0.017
#     S95.srvy.ndrct   -0.040
#     S95.survey.ttl    0.017
