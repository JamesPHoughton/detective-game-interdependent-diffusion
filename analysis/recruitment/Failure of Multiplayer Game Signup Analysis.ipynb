# %%
# %pylab inline
import pandas as pd
import json
import datetime
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
hitid = '30EV7DWJTUUBPZRXGGL2A0PGANYY6K'
date = "2019-07-09"

# %%
data = pd.read_csv("Empirica Data - 2019-07-10 19-17-54/players.csv", parse_dates=['readyAt', 'createdAt', 'exitAt'])
data.fillna(0, inplace=True)
data['urlParams'] = data['urlParams'].apply(lambda x: json.loads(x))
data['TurkID'] = data['urlParams'].apply(lambda x: x['workerId'] if 'workerId' in x.keys() else "")
data['HITID'] = data['urlParams'].apply(lambda x: x['hitId'] if 'hitId' in x.keys() else "")
data['BasePay'] = data['exitStatus'].apply(lambda s: 1 if s == "finished" else .25)
data['Date'] = data['createdAt'].apply(lambda s: str(s).split(' ')[0])
data = data[data['Date']==date]
data
# Out:
#                   _id                                                 id  \
# 77  Q3spRdMtiCjaoNBq2  James (Retired gameLobbyTimedOut at 2019-07-10...
# 78  oBhKoY8GTTX7nE3Ho  A2PZG5F8RIESH9 (Retired gameLobbyTimedOut at 2...
# 79  e9ShgrJnwons8qWGp  AE63GABJL0FGJ (Retired gameLobbyTimedOut at 20...
# 80  tJkCvkiXdtntHaAGx  A1945USNZHTROX (Retired gameLobbyTimedOut at 2...
# 81  HzWrMZzEQQjj2X255  A1M24593XO5Z3C (Retired gameLobbyTimedOut at 2...
# 82  JFrJD5CZJrWtSs75o  A2RCYLKY072XXO (Retired gameLobbyTimedOut at 2...
# 83  yAT7nj5guEqLcJyqn  A52FUUEDGSZT9 (Retired gameLobbyTimedOut at 20...
# 84  M9Mxk5xKsiGW3Na9Z  A191V7PT3DQKDP (Retired gameLobbyTimedOut at 2...
# 85  JAoxyxu4Eq4ppa5fD  A1NVJB5O4H7ZCJ (Retired gameLobbyTimedOut at 2...
# 86  PvrbEubapw8i87smc  A1IEAOCJNSPVRX (Retired gameLobbyTimedOut at 2...
# 87  o28cSYD9xRsDJKXiR  A1QRGVE005067Q (Retired gameLobbyTimedOut at 2...
# 88  dwpBAqbCbW2jfAhBn  A270HX8LH9LJ8W (Retired gameLobbyTimedOut at 2...
# 89  wpPTuaeZDzngnLrZJ  A3388HIWAKD3DV (Retired gameLobbyTimedOut at 2...
# 90  nE8E9mP8GMKnk4bvr  A3OVGQIGX8BAB4 (Retired gameLobbyTimedOut at 2...
# 91  ba7ZxD4FjF2y27AGF  AHIJACUG7ZL9B (Retired gameLobbyTimedOut at 20...
# 92  trFeA5yst3u2jMSkP  ACGZDI611LU0I (Retired gameLobbyTimedOut at 20...
# 93  vsphkemQi68WpfDQL  A2XQ3CFB5HT2ZQ (Retired gameLobbyTimedOut at 2...
# 94  mXgmQH3tZaKkBuCAW  A2DVV59R1CQU6T (Retired gameLobbyTimedOut at 2...
# 95  sxTBcDjZMyuwJ74FJ  A1ROEDVMTO9Y3X (Retired gameLobbyTimedOut at 2...
# 96  JBLz3A4Gg6pGvatdR  A16G6PPH1INQL8 (Retired gameLobbyTimedOut at 2...
# 97  oPQYFd28NNRojyru7  A26M997VYVK0E6 (Retired gameLobbyTimedOut at 2...
#
#                                             urlParams  bot  \
# 77  {'hitId': 'HIT_ID', 'workerId': 'A_WORKER_ID',...  0.0
# 78  {'hitId': '3BFF0DJK8WBKVBQ0DN163OTTD8YTST', 'w...  0.0
# 79  {'hitId': '3BFF0DJK8WBKVBQ0DN163OTTD8YTST', 'w...  0.0
# 80  {'hitId': '3BFF0DJK8WBKVBQ0DN163OTTD8YTST', 'w...  0.0
# 81  {'hitId': '3BFF0DJK8WBKVBQ0DN163OTTD8YTST', 'w...  0.0
# 82  {'hitId': '3BFF0DJK8WBKVBQ0DN163OTTD8YTST', 'w...  0.0
# 83  {'hitId': '3BFF0DJK8WBKVBQ0DN163OTTD8YTST', 'w...  0.0
# 84  {'hitId': '3BFF0DJK8WBKVBQ0DN163OTTD8YTST', 'w...  0.0
# 85  {'hitId': '3BFF0DJK8WBKVBQ0DN163OTTD8YTST', 'w...  0.0
# 86  {'hitId': '3BFF0DJK8WBKVBQ0DN163OTTD8YTST', 'w...  0.0
# 87  {'hitId': '3BFF0DJK8WBKVBQ0DN163OTTD8YTST', 'w...  0.0
# 88  {'hitId': '3BFF0DJK8WBKVBQ0DN163OTTD8YTST', 'w...  0.0
# 89  {'hitId': '3BFF0DJK8WBKVBQ0DN163OTTD8YTST', 'w...  0.0
# 90  {'hitId': '3BFF0DJK8WBKVBQ0DN163OTTD8YTST', 'w...  0.0
# 91  {'hitId': '3BFF0DJK8WBKVBQ0DN163OTTD8YTST', 'w...  0.0
# 92  {'hitId': '3BFF0DJK8WBKVBQ0DN163OTTD8YTST', 'w...  0.0
# 93  {'hitId': '3BFF0DJK8WBKVBQ0DN163OTTD8YTST', 'w...  0.0
# 94  {'hitId': '3BFF0DJK8WBKVBQ0DN163OTTD8YTST', 'w...  0.0
# 95  {'hitId': '3BFF0DJK8WBKVBQ0DN163OTTD8YTST', 'w...  0.0
# 96  {'hitId': '3BFF0DJK8WBKVBQ0DN163OTTD8YTST', 'w...  0.0
# 97  {'hitId': '3BFF0DJK8WBKVBQ0DN163OTTD8YTST', 'w...  0.0
#
#                       readyAt  timeoutStartedAt  timeoutWaitCount  \
# 77  2019-07-09 18:35:03+00:00               0.0               0.0
# 78  2019-07-09 18:36:36+00:00               0.0               0.0
# 79  2019-07-09 18:38:26+00:00               0.0               0.0
# 80  2019-07-09 18:37:21+00:00               0.0               0.0
# 81  2019-07-09 18:37:17+00:00               0.0               0.0
# 82  2019-07-09 18:38:42+00:00               0.0               0.0
# 83  2019-07-09 18:38:54+00:00               0.0               0.0
# 84  2019-07-09 18:39:29+00:00               0.0               0.0
# 85  2019-07-09 18:42:22+00:00               0.0               0.0
# 86  2019-07-09 18:44:38+00:00               0.0               0.0
# 87  2019-07-09 18:43:41+00:00               0.0               0.0
# 88  2019-07-09 18:44:39+00:00               0.0               0.0
# 89  2019-07-09 18:49:45+00:00               0.0               0.0
# 90  2019-07-09 18:45:21+00:00               0.0               0.0
# 91  2019-07-09 18:46:45+00:00               0.0               0.0
# 92  2019-07-09 18:48:58+00:00               0.0               0.0
# 93                          0               0.0               0.0
# 94  2019-07-09 18:49:55+00:00               0.0               0.0
# 95                          0               0.0               0.0
# 96                          0               0.0               0.0
# 97                          0               0.0               0.0
#
#    exitStepsDone                    exitAt         exitStatus  ...  \
# 77             0 2019-07-09 18:50:03+00:00  gameLobbyTimedOut  ...
# 78             0 2019-07-09 18:50:03+00:00  gameLobbyTimedOut  ...
# 79             0 2019-07-09 18:50:03+00:00  gameLobbyTimedOut  ...
# 80             0 2019-07-09 18:50:03+00:00  gameLobbyTimedOut  ...
# 81             0 2019-07-09 18:50:03+00:00  gameLobbyTimedOut  ...
# 82             0 2019-07-09 18:50:03+00:00  gameLobbyTimedOut  ...
# 83             0 2019-07-09 18:50:03+00:00  gameLobbyTimedOut  ...
# 84             0 2019-07-09 18:50:03+00:00  gameLobbyTimedOut  ...
# 85             0 2019-07-09 18:50:03+00:00  gameLobbyTimedOut  ...
# 86             0 2019-07-09 18:50:03+00:00  gameLobbyTimedOut  ...
# 87             0 2019-07-09 18:50:03+00:00  gameLobbyTimedOut  ...
# 88             0 2019-07-09 18:50:03+00:00  gameLobbyTimedOut  ...
# 89             0 2019-07-09 18:50:03+00:00  gameLobbyTimedOut  ...
# 90             0 2019-07-09 18:50:03+00:00  gameLobbyTimedOut  ...
# 91             0 2019-07-09 18:50:03+00:00  gameLobbyTimedOut  ...
# 92             0 2019-07-09 18:50:03+00:00  gameLobbyTimedOut  ...
# 93             0 2019-07-09 18:50:03+00:00  gameLobbyTimedOut  ...
# 94             0 2019-07-09 18:50:03+00:00  gameLobbyTimedOut  ...
# 95             0 2019-07-09 18:50:03+00:00  gameLobbyTimedOut  ...
# 96             0 2019-07-09 18:50:03+00:00  gameLobbyTimedOut  ...
# 97             0 2019-07-09 18:50:03+00:00  gameLobbyTimedOut  ...
#
#    data.caseMade data.individualBonus data.teamBonus  data.totalPay  \
# 77             0                  0.0            0.0            0.0
# 78             0                  0.0            0.0            0.0
# 79             0                  0.0            0.0            0.0
# 80             0                  0.0            0.0            0.0
# 81             0                  0.0            0.0            0.0
# 82             0                  0.0            0.0            0.0
# 83             0                  0.0            0.0            0.0
# 84             0                  0.0            0.0            0.0
# 85             0                  0.0            0.0            0.0
# 86             0                  0.0            0.0            0.0
# 87             0                  0.0            0.0            0.0
# 88             0                  0.0            0.0            0.0
# 89             0                  0.0            0.0            0.0
# 90             0                  0.0            0.0            0.0
# 91             0                  0.0            0.0            0.0
# 92             0                  0.0            0.0            0.0
# 93             0                  0.0            0.0            0.0
# 94             0                  0.0            0.0            0.0
# 95             0                  0.0            0.0            0.0
# 96             0                  0.0            0.0            0.0
# 97             0                  0.0            0.0            0.0
#
#    data.survey data.active          TurkID                           HITID  \
# 77           0           0     A_WORKER_ID                          HIT_ID
# 78           0           0  A2PZG5F8RIESH9  3BFF0DJK8WBKVBQ0DN163OTTD8YTST
# 79           0           0   AE63GABJL0FGJ  3BFF0DJK8WBKVBQ0DN163OTTD8YTST
# 80           0           0  A1945USNZHTROX  3BFF0DJK8WBKVBQ0DN163OTTD8YTST
# 81           0           0  A1M24593XO5Z3C  3BFF0DJK8WBKVBQ0DN163OTTD8YTST
# 82           0           0  A2RCYLKY072XXO  3BFF0DJK8WBKVBQ0DN163OTTD8YTST
# 83           0           0   A52FUUEDGSZT9  3BFF0DJK8WBKVBQ0DN163OTTD8YTST
# 84           0           0  A191V7PT3DQKDP  3BFF0DJK8WBKVBQ0DN163OTTD8YTST
# 85           0           0  A1NVJB5O4H7ZCJ  3BFF0DJK8WBKVBQ0DN163OTTD8YTST
# 86           0           0  A1IEAOCJNSPVRX  3BFF0DJK8WBKVBQ0DN163OTTD8YTST
# 87           0           0  A1QRGVE005067Q  3BFF0DJK8WBKVBQ0DN163OTTD8YTST
# 88           0           0  A270HX8LH9LJ8W  3BFF0DJK8WBKVBQ0DN163OTTD8YTST
# 89           0           0  A3388HIWAKD3DV  3BFF0DJK8WBKVBQ0DN163OTTD8YTST
# 90           0           0  A3OVGQIGX8BAB4  3BFF0DJK8WBKVBQ0DN163OTTD8YTST
# 91           0           0   AHIJACUG7ZL9B  3BFF0DJK8WBKVBQ0DN163OTTD8YTST
# 92           0           0   ACGZDI611LU0I  3BFF0DJK8WBKVBQ0DN163OTTD8YTST
# 93           0           0  A2XQ3CFB5HT2ZQ  3BFF0DJK8WBKVBQ0DN163OTTD8YTST
# 94           0           0  A2DVV59R1CQU6T  3BFF0DJK8WBKVBQ0DN163OTTD8YTST
# 95           0           0  A1ROEDVMTO9Y3X  3BFF0DJK8WBKVBQ0DN163OTTD8YTST
# 96           0           0  A16G6PPH1INQL8  3BFF0DJK8WBKVBQ0DN163OTTD8YTST
# 97           0           0  A26M997VYVK0E6  3BFF0DJK8WBKVBQ0DN163OTTD8YTST
#
#    BasePay        Date
# 77    0.25  2019-07-09
# 78    0.25  2019-07-09
# 79    0.25  2019-07-09
# 80    0.25  2019-07-09
# 81    0.25  2019-07-09
# 82    0.25  2019-07-09
# 83    0.25  2019-07-09
# 84    0.25  2019-07-09
# 85    0.25  2019-07-09
# 86    0.25  2019-07-09
# 87    0.25  2019-07-09
# 88    0.25  2019-07-09
# 89    0.25  2019-07-09
# 90    0.25  2019-07-09
# 91    0.25  2019-07-09
# 92    0.25  2019-07-09
# 93    0.25  2019-07-09
# 94    0.25  2019-07-09
# 95    0.25  2019-07-09
# 96    0.25  2019-07-09
# 97    0.25  2019-07-09
#
# [21 rows x 32 columns]

# %%
d2 = data.set_index('createdAt').sort_index()
d2['one'] = 1
d2['Players Joined'] = d2['one'].cumsum()
d2['Players Joined'].iloc[1:].plot();

# %%
d3 = data[data['readyAt'] != 0].set_index('readyAt').sort_index()
d3['one'] = 1
d3['Players Ready'] = d3['one'].cumsum()
d3['Players Ready'].iloc[1:].plot()

# %%
d4 = data.set_index('exitAt').sort_index()
d4['one'] = 1
d4['Players Finished'] = d4['one'].cumsum()
d4['Players Finished'].iloc[1:].plot()
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py:1001: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=737249.7847569444, right=737249.7847569444
#   ax.set_xlim(left, right)

# %%
tp_df = pd.read_csv('DG Pilot 2 Jul09.csv', parse_dates=['StartTime', 'CompletionTime'])
tp_df['StartTime'] = tp_df['StartTime'].apply(lambda t: t.tz_localize('UTC'))
d5 = tp_df.set_index('StartTime').sort_index()
d5['one'] = 1
d5['Players Entered'] = d5['one'].cumsum()
d5['Players Entered'].iloc[1:].plot()

# %%
tp_df['CompletionTime'] = tp_df['CompletionTime'].apply(lambda t: t.tz_localize('UTC'))
d6 = tp_df.set_index('CompletionTime').sort_index()
d6['one'] = 1
d6['Players Left'] = d6['one'].cumsum()
d6['Players Left'].iloc[1:].plot()

# %%
mdf = pd.merge(d3[['Players Ready']], d2[['Players Joined']], left_index=True, right_index=True, how='outer')
mdf = pd.merge(mdf, d4[['Players Finished','exitStatus']], left_index=True, right_index=True, how='outer')
mdf = pd.merge(mdf, d5[['Players Entered']], left_index=True, right_index=True, how='outer')
mdf = pd.merge(mdf, d6[['Players Left']], left_index=True, right_index=True, how='outer')
mdf = mdf.sort_index().fillna(method='ffill').fillna(0)

mdf['Players Online'] = mdf['Players Entered'] - mdf['Players Left'] + 2

mdf['Players On Site'] = mdf['Players Joined'] - mdf['Players Finished']
mdf['Players Active'] = np.minimum(mdf['Players Ready'], mdf['Players On Site'])
mdf['Players Training'] = mdf['Players On Site'] - mdf['Players Active']

mdf['Players in Intro/Exit'] = mdf['Players Online'] - mdf['Players On Site']

mdf[['Players Active', 'Players Training', 'Players in Intro/Exit']].iloc[2:].plot(kind='area', linewidth=0, alpha=.5)
plt.box('off')
plt.xlim(pd.Timestamp('07/09/19 18:33',tz='UTC'), pd.Timestamp('07/9/19 18:55',tz='UTC'))
handles, labels = plt.gca().get_legend_handles_labels()
plt.legend(handles[::-1], labels[::-1], loc='lower center', bbox_to_anchor=(.5,1), ncol=3, frameon=False)
plt.hlines(20, *plt.gca().get_xlim(), color='darkgrey')
start = mdf[mdf['exitStatus']!=0].index[0]
plt.vlines(pd.Timestamp('07/09/19 18:34',tz='UTC'), *plt.gca().get_ylim(), color='darkgrey') # HIT launch
plt.vlines(start, *plt.gca().get_ylim(), color='r')
tickpos, ticklabels = plt.xticks()
#plt.vlines(tickpos[3], 0,12, color='r', linestyle='--', alpha=.5)
#plt.gca().set_xticklabels([s.get_text().split(' ')[-1] for s in ticklabels], rotation=0)

#plt.text(start, 22, "   Players dropped\n   from training")
plt.text(start, 15, "       Players\n     Dropped")
plt.text(start, 5, "Players         \nin lobby        ", ha='right')
#plt.text(tickpos[3], 0, "  Advertised Time", rotation=90, color='r', va='bottom', ha='right')
plt.text(start, 0, "  Lobby Timeout", rotation=90, color='r', va='bottom', ha='right')
plt.text(pd.Timestamp('07/09/19 18:34',tz='UTC'), 0, "  HIT released", rotation=90, color='darkgrey', va='bottom', ha='right')
plt.text(pd.Timestamp('07/09/19 18:34',tz='UTC'), 20, "   Launch Threshold", color="darkgrey", ha='left', va='bottom')
plt.suptitle("Failed Launch, no quals, 50 HITS", y=1)
plt.ylabel('Players')
plt.yticks(range(0,21,5))
plt.tight_layout()

# %%
mdf[['Players Entered', 'Players Left', 'Players Online']].plot();

# %%
mdf[['Players Joined', 'Players Finished']].plot();

# %%
mdf[['Players Online', 'Players On Site']].plot();
