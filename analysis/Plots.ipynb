# %% [markdown]
# # Experiment Plots
#
# This notebook takes the processed and stored data and generates figure 4

# %%
# %pylab inline

rcParamsDefault = plt.rcParams
import pandas as pd

import matplotlib.image as mpimg
import matplotlib as mpl
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# load the aggregate data

wd = "../results-anonymized/experiment/"
end_of_game = pd.read_csv(wd+"end_of_game_effects_summary.csv", index_col=[0,1])

end_of_game['Effect Upper Error'] = end_of_game['Effect Upper Bound'] - end_of_game['Effect Size']
end_of_game['Effect Lower Error'] = end_of_game['Effect Size'] - end_of_game['Effect Lower Bound']

end_of_game
# Out:
#                                                Result Mean  \
# ('caveman', 'indep') confidence                  56.075477
#                      consensus                   57.647486
#                      net spoke 5% similarity     -0.115199
#                      net spoke 95% similarity     0.253323
#                      net spoke PC1                0.190110
#                      spoke 5% similarity         -0.271291
#                      spoke 95% similarity         0.803906
#                      spoke PC1                    0.387681
#                      survey 5% similarity        -0.497605
#                      survey 95% similarity        0.689841
#                      survey PC1                   0.380187
# ('caveman', 'inter') confidence                  59.130604
#                      consensus                   56.931033
#                      net spoke 5% similarity     -0.111787
#                      net spoke 95% similarity     0.255335
#                      net spoke PC1                0.194040
#                      spoke 5% similarity         -0.303028
#                      spoke 95% similarity         0.777318
#                      spoke PC1                    0.391874
#                      survey 5% similarity        -0.491553
#                      survey 95% similarity        0.704249
#                      survey PC1                   0.362617
# ('dodec', 'indep')   confidence                  55.393503
#                      consensus                   55.892335
#                      net spoke 5% similarity     -0.081649
#                      net spoke 95% similarity     0.096172
#                      net spoke PC1                0.053479
#                      spoke 5% similarity         -0.157664
#                      spoke 95% similarity         0.688170
#                      spoke PC1                    0.296064
#                      survey 5% similarity        -0.408854
#                      survey 95% similarity        0.668364
#                      survey PC1                   0.308066
# ('dodec', 'inter')   confidence                  57.561825
#                      consensus                   55.268431
#                      net spoke 5% similarity     -0.071222
#                      net spoke 95% similarity     0.121914
#                      net spoke PC1                0.074821
#                      spoke 5% similarity         -0.215429
#                      spoke 95% similarity         0.672197
#                      spoke PC1                    0.292582
#                      survey 5% similarity        -0.442980
#                      survey 95% similarity        0.664479
#                      survey PC1                   0.336152
#
#                                                Result Lower Bound  \
# ('caveman', 'indep') confidence                         54.522697
#                      consensus                          56.113827
#                      net spoke 5% similarity            -0.131451
#                      net spoke 95% similarity            0.229759
#                      net spoke PC1                       0.174641
#                      spoke 5% similarity                -0.301361
#                      spoke 95% similarity                0.787882
#                      spoke PC1                           0.372614
#                      survey 5% similarity               -0.523360
#                      survey 95% similarity               0.670010
#                      survey PC1                          0.362474
# ('caveman', 'inter') confidence                         57.611790
#                      consensus                          55.305269
#                      net spoke 5% similarity            -0.127078
#                      net spoke 95% similarity            0.233353
#                      net spoke PC1                       0.177167
#                      spoke 5% similarity                -0.329362
#                      spoke 95% similarity                0.759451
#                      spoke PC1                           0.374795
#                      survey 5% similarity               -0.523878
#                      survey 95% similarity               0.680504
#                      survey PC1                          0.346118
# ('dodec', 'indep')   confidence                         53.366473
#                      consensus                          54.154642
#                      net spoke 5% similarity            -0.093593
#                      net spoke 95% similarity            0.080823
#                      net spoke PC1                       0.042749
#                      spoke 5% similarity                -0.186562
#                      spoke 95% similarity                0.671173
#                      spoke PC1                           0.281489
#                      survey 5% similarity               -0.432917
#                      survey 95% similarity               0.648751
#                      survey PC1                          0.292744
# ('dodec', 'inter')   confidence                         55.074905
#                      consensus                          53.108790
#                      net spoke 5% similarity            -0.089750
#                      net spoke 95% similarity            0.104355
#                      net spoke PC1                       0.061364
#                      spoke 5% similarity                -0.243120
#                      spoke 95% similarity                0.649878
#                      spoke PC1                           0.276110
#                      survey 5% similarity               -0.464038
#                      survey 95% similarity               0.641974
#                      survey PC1                          0.320389
#
#                                                Result Upper Bound  \
# ('caveman', 'indep') confidence                         57.659396
#                      consensus                          59.246244
#                      net spoke 5% similarity            -0.099820
#                      net spoke 95% similarity            0.277272
#                      net spoke PC1                       0.205675
#                      spoke 5% similarity                -0.239795
#                      spoke 95% similarity                0.819420
#                      spoke PC1                           0.402959
#                      survey 5% similarity               -0.470746
#                      survey 95% similarity               0.709450
#                      survey PC1                          0.400242
# ('caveman', 'inter') confidence                         60.633187
#                      consensus                          58.579631
#                      net spoke 5% similarity            -0.096011
#                      net spoke 95% similarity            0.277346
#                      net spoke PC1                       0.211197
#                      spoke 5% similarity                -0.271104
#                      spoke 95% similarity                0.795017
#                      spoke PC1                           0.410800
#                      survey 5% similarity               -0.457351
#                      survey 95% similarity               0.728930
#                      survey PC1                          0.380586
# ('dodec', 'indep')   confidence                         57.280736
#                      consensus                          57.550229
#                      net spoke 5% similarity            -0.069062
#                      net spoke 95% similarity            0.112024
#                      net spoke PC1                       0.064819
#                      spoke 5% similarity                -0.124849
#                      spoke 95% similarity                0.704569
#                      spoke PC1                           0.309388
#                      survey 5% similarity               -0.385043
#                      survey 95% similarity               0.689818
#                      survey PC1                          0.324400
# ('dodec', 'inter')   confidence                         59.938405
#                      consensus                          57.134647
#                      net spoke 5% similarity            -0.056167
#                      net spoke 95% similarity            0.140271
#                      net spoke PC1                       0.092521
#                      spoke 5% similarity                -0.188938
#                      spoke 95% similarity                0.695965
#                      spoke PC1                           0.309164
#                      survey 5% similarity               -0.422233
#                      survey 95% similarity               0.685256
#                      survey PC1                          0.353003
#
#                                                Effect Size  \
# ('caveman', 'indep') confidence                   0.681974
#                      consensus                    1.755151
#                      net spoke 5% similarity     -0.033550
#                      net spoke 95% similarity     0.157151
#                      net spoke PC1                0.136630
#                      spoke 5% similarity         -0.113627
#                      spoke 95% similarity         0.115736
#                      spoke PC1                    0.091616
#                      survey 5% similarity        -0.088750
#                      survey 95% similarity        0.021477
#                      survey PC1                   0.072120
# ('caveman', 'inter') confidence                   3.737101
#                      consensus                    1.038699
#                      net spoke 5% similarity     -0.030138
#                      net spoke 95% similarity     0.159163
#                      net spoke PC1                0.140561
#                      spoke 5% similarity         -0.145364
#                      spoke 95% similarity         0.089148
#                      spoke PC1                    0.095810
#                      survey 5% similarity        -0.082699
#                      survey 95% similarity        0.035884
#                      survey PC1                   0.054551
# ('dodec', 'indep')   confidence                   0.000000
#                      consensus                    0.000000
#                      net spoke 5% similarity      0.000000
#                      net spoke 95% similarity     0.000000
#                      net spoke PC1                0.000000
#                      spoke 5% similarity          0.000000
#                      spoke 95% similarity         0.000000
#                      spoke PC1                    0.000000
#                      survey 5% similarity         0.000000
#                      survey 95% similarity        0.000000
#                      survey PC1                   0.000000
# ('dodec', 'inter')   confidence                   2.168322
#                      consensus                   -0.623904
#                      net spoke 5% similarity      0.010427
#                      net spoke 95% similarity     0.025742
#                      net spoke PC1                0.021341
#                      spoke 5% similarity         -0.057765
#                      spoke 95% similarity        -0.015973
#                      spoke PC1                   -0.003482
#                      survey 5% similarity        -0.034126
#                      survey 95% similarity       -0.003886
#                      survey PC1                   0.028085
#
#                                                Effect Upper Bound  \
# ('caveman', 'indep') confidence                          3.378369
#                      consensus                           3.957550
#                      net spoke 5% similarity            -0.015665
#                      net spoke 95% similarity            0.185778
#                      net spoke PC1                       0.158771
#                      spoke 5% similarity                -0.071640
#                      spoke 95% similarity                0.139116
#                      spoke PC1                           0.110747
#                      survey 5% similarity               -0.057349
#                      survey 95% similarity               0.050519
#                      survey PC1                          0.097728
# ('caveman', 'inter') confidence                          6.345613
#                      consensus                           3.302240
#                      net spoke 5% similarity            -0.010221
#                      net spoke 95% similarity            0.183336
#                      net spoke PC1                       0.161156
#                      spoke 5% similarity                -0.111149
#                      spoke 95% similarity                0.110200
#                      spoke PC1                           0.121812
#                      survey 5% similarity               -0.040245
#                      survey 95% similarity               0.058107
#                      survey PC1                          0.076335
# ('dodec', 'indep')   confidence                          0.000000
#                      consensus                           0.000000
#                      net spoke 5% similarity             0.000000
#                      net spoke 95% similarity            0.000000
#                      net spoke PC1                       0.000000
#                      spoke 5% similarity                 0.000000
#                      spoke 95% similarity                0.000000
#                      spoke PC1                           0.000000
#                      survey 5% similarity                0.000000
#                      survey 95% similarity               0.000000
#                      survey PC1                          0.000000
# ('dodec', 'inter')   confidence                          4.335920
#                      consensus                           1.347957
#                      net spoke 5% similarity             0.031669
#                      net spoke 95% similarity            0.044564
#                      net spoke PC1                       0.037212
#                      spoke 5% similarity                -0.022883
#                      spoke 95% similarity                0.009608
#                      spoke PC1                           0.017070
#                      survey 5% similarity                0.001532
#                      survey 95% similarity               0.022675
#                      survey PC1                          0.050295
#
#                                                Effect Lower Bound  \
# ('caveman', 'indep') confidence                         -1.505420
#                      consensus                          -0.364096
#                      net spoke 5% similarity            -0.053567
#                      net spoke 95% similarity            0.125858
#                      net spoke PC1                       0.115025
#                      spoke 5% similarity                -0.156118
#                      spoke 95% similarity                0.094198
#                      spoke PC1                           0.072683
#                      survey 5% similarity               -0.123563
#                      survey 95% similarity              -0.009894
#                      survey PC1                          0.048142
# ('caveman', 'inter') confidence                          1.357033
#                      consensus                          -1.184578
#                      net spoke 5% similarity            -0.048770
#                      net spoke 95% similarity            0.133753
#                      net spoke PC1                       0.120690
#                      spoke 5% similarity                -0.179943
#                      spoke 95% similarity                0.068177
#                      spoke PC1                           0.072203
#                      survey 5% similarity               -0.121184
#                      survey 95% similarity               0.014808
#                      survey PC1                          0.031102
# ('dodec', 'indep')   confidence                          0.000000
#                      consensus                           0.000000
#                      net spoke 5% similarity             0.000000
#                      net spoke 95% similarity            0.000000
#                      net spoke PC1                       0.000000
#                      spoke 5% similarity                 0.000000
#                      spoke 95% similarity                0.000000
#                      spoke PC1                           0.000000
#                      survey 5% similarity                0.000000
#                      survey 95% similarity               0.000000
#                      survey PC1                          0.000000
# ('dodec', 'inter')   confidence                          0.201013
#                      consensus                          -2.729174
#                      net spoke 5% similarity            -0.012293
#                      net spoke 95% similarity            0.008312
#                      net spoke PC1                       0.006063
#                      spoke 5% similarity                -0.091266
#                      spoke 95% similarity               -0.042963
#                      spoke PC1                          -0.023995
#                      survey 5% similarity               -0.066697
#                      survey 95% similarity              -0.030973
#                      survey PC1                          0.005726
#
#                                                Effect P Value  \
# ('caveman', 'indep') confidence                  3.226729e-01
#                      consensus                   8.686126e-02
#                      net spoke 5% similarity     4.316467e-03
#                      net spoke 95% similarity    1.170606e-09
#                      net spoke PC1               2.074857e-11
#                      spoke 5% similarity         6.620324e-05
#                      spoke 95% similarity        2.094433e-09
#                      spoke PC1                   1.867367e-08
#                      survey 5% similarity        6.348414e-05
#                      survey 95% similarity       1.230062e-01
#                      survey PC1                  2.319298e-05
# ('caveman', 'inter') confidence                  1.196324e-02
#                      consensus                   2.308408e-01
#                      net spoke 5% similarity     1.002319e-02
#                      net spoke 95% similarity    1.514391e-11
#                      net spoke PC1               2.797712e-12
#                      spoke 5% similarity         8.120113e-08
#                      spoke 95% similarity        7.135142e-08
#                      spoke PC1                   1.839115e-07
#                      survey 5% similarity        1.479175e-03
#                      survey 95% similarity       5.817627e-03
#                      survey PC1                  3.462838e-04
# ('dodec', 'indep')   confidence                           NaN
#                      consensus                            NaN
#                      net spoke 5% similarity              NaN
#                      net spoke 95% similarity             NaN
#                      net spoke PC1                        NaN
#                      spoke 5% similarity                  NaN
#                      spoke 95% similarity                 NaN
#                      spoke PC1                            NaN
#                      survey 5% similarity                 NaN
#                      survey 95% similarity                NaN
#                      survey PC1                           NaN
# ('dodec', 'inter')   confidence                  4.513818e-02
#                      consensus                   3.110859e-01
#                      net spoke 5% similarity     2.173495e-01
#                      net spoke 95% similarity    1.497205e-02
#                      net spoke PC1               1.634738e-02
#                      spoke 5% similarity         4.596072e-03
#                      spoke 95% similarity        1.679677e-01
#                      spoke PC1                   3.895726e-01
#                      survey 5% similarity        5.834384e-02
#                      survey 95% similarity       4.137002e-01
#                      survey PC1                  2.166481e-02
#
#                                                Effect Upper Error  \
# ('caveman', 'indep') confidence                          2.696395
#                      consensus                           2.202398
#                      net spoke 5% similarity             0.017884
#                      net spoke 95% similarity            0.028627
#                      net spoke PC1                       0.022141
#                      spoke 5% similarity                 0.041987
#                      spoke 95% similarity                0.023379
#                      spoke PC1                           0.019131
#                      survey 5% similarity                0.031401
#                      survey 95% similarity               0.029042
#                      survey PC1                          0.025608
# ('caveman', 'inter') confidence                          2.608512
#                      consensus                           2.263541
#                      net spoke 5% similarity             0.019917
#                      net spoke 95% similarity            0.024173
#                      net spoke PC1                       0.020596
#                      spoke 5% similarity                 0.034215
#                      spoke 95% similarity                0.021053
#                      spoke PC1                           0.026003
#                      survey 5% similarity                0.042454
#                      survey 95% similarity               0.022222
#                      survey PC1                          0.021784
# ('dodec', 'indep')   confidence                          0.000000
#                      consensus                           0.000000
#                      net spoke 5% similarity             0.000000
#                      net spoke 95% similarity            0.000000
#                      net spoke PC1                       0.000000
#                      spoke 5% similarity                 0.000000
#                      spoke 95% similarity                0.000000
#                      spoke PC1                           0.000000
#                      survey 5% similarity                0.000000
#                      survey 95% similarity               0.000000
#                      survey PC1                          0.000000
# ('dodec', 'inter')   confidence                          2.167598
#                      consensus                           1.971861
#                      net spoke 5% similarity             0.021242
#                      net spoke 95% similarity            0.018822
#                      net spoke PC1                       0.015871
#                      spoke 5% similarity                 0.034882
#                      spoke 95% similarity                0.025581
#                      spoke PC1                           0.020552
#                      survey 5% similarity                0.035657
#                      survey 95% similarity               0.026561
#                      survey PC1                          0.022210
#
#                                                Effect Lower Error
# ('caveman', 'indep') confidence                          2.187394
#                      consensus                           2.119248
#                      net spoke 5% similarity             0.020017
#                      net spoke 95% similarity            0.031293
#                      net spoke PC1                       0.021605
#                      spoke 5% similarity                 0.042491
#                      spoke 95% similarity                0.021539
#                      spoke PC1                           0.018934
#                      survey 5% similarity                0.034812
#                      survey 95% similarity               0.031371
#                      survey PC1                          0.023978
# ('caveman', 'inter') confidence                          2.380068
#                      consensus                           2.223277
#                      net spoke 5% similarity             0.018631
#                      net spoke 95% similarity            0.025410
#                      net spoke PC1                       0.019870
#                      spoke 5% similarity                 0.034579
#                      spoke 95% similarity                0.020971
#                      spoke PC1                           0.023607
#                      survey 5% similarity                0.038485
#                      survey 95% similarity               0.021076
#                      survey PC1                          0.023449
# ('dodec', 'indep')   confidence                          0.000000
#                      consensus                           0.000000
#                      net spoke 5% similarity             0.000000
#                      net spoke 95% similarity            0.000000
#                      net spoke PC1                       0.000000
#                      spoke 5% similarity                 0.000000
#                      spoke 95% similarity                0.000000
#                      spoke PC1                           0.000000
#                      survey 5% similarity                0.000000
#                      survey 95% similarity               0.000000
#                      survey PC1                          0.000000
# ('dodec', 'inter')   confidence                          1.967309
#                      consensus                           2.105270
#                      net spoke 5% similarity             0.022720
#                      net spoke 95% similarity            0.017429
#                      net spoke PC1                       0.015279
#                      spoke 5% similarity                 0.033501
#                      spoke 95% similarity                0.026990
#                      spoke PC1                           0.020513
#                      survey 5% similarity                0.032571
#                      survey 95% similarity               0.027087
#                      survey PC1                          0.022359

# %%
# load raw data for each game (for dots in figure)

raw = pd.read_csv(wd+"end_of_game_measurements.csv")
pairs = raw[raw['network']==0] # only dodec network
cols=['net spoke 5% similarity', 'net spoke 95% similarity', 'net spoke PC1', 
      'survey 5% similarity', 'survey 95% similarity','survey PC1']

# dots represent effect observed in a single game pair
dots = pairs.groupby('id').apply(lambda g: g[g['t']==1][cols].reset_index() - g[g['t']==0][cols].reset_index())
dots
# Out:
#                      index  net spoke 5% similarity  net spoke 95% similarity  \
# id
# 7c9biMCakuPCxMEXN 0      1                 0.055318                  0.035597
# 7kcXpJaQqJmx68nYz 0      1                 0.025583                 -0.043749
# BfWPcLgXY7dKcAsdX 0      1                -0.042693                 -0.002579
# BhccgcKQe7bpH7pWi 0      1                -0.062338                  0.000925
# EFdcytJKJJAgFebvR 0      1                 0.037694                  0.058083
# ETYJ4Ru9uE3Fszkkr 0      1                -0.032705                  0.002867
# F6g9NDczqP966pA5m 0      1                 0.036598                 -0.007078
# KtFjB6pDKRispFwCs 0      1                 0.087919                 -0.003314
# Lj2up2ePZA6WtiK4q 0      1                 0.046936                  0.056881
# MfjKnfErfu8AMLKps 0      1                 0.009169                  0.027568
# RugWRCuQ9MounHF8x 0      1                 0.075029                 -0.049066
# SamzHPveTXj44MS6F 0      1                -0.036552                 -0.021632
# T9KCzCFiibi6W5mnL 0      1                 0.013102                 -0.030523
# TCrgRvccdKGHeDvdW 0      1                -0.064416                  0.100632
# W3Pr3tyHAoPsyoZxh 0      1                 0.040267                  0.033531
# Zxhtd5NFdLyNExLtN 0      1                 0.128667                 -0.073168
# aS5rH5N5tnRsr3CQQ 0      1                -0.066448                  0.110088
# c2BKscFKSBaujzQHw 0      1                 0.012115                  0.122713
# d2N6gipGzAM2B3GPn 0      1                -0.190954                  0.032997
# dC7qKt8rhj8W3FFTC 0      1                 0.116382                 -0.116447
# e6Kq4iEPeKDdJ3wyk 0      1                -0.045618                  0.083409
# hE8iDmuY7wvbgTTRB 0      1                 0.018256                  0.027047
# hjTbDvCzT2RW9pgm8 0      1                 0.146518                  0.018668
# ig8z4GCN3uW4nFT54 0      1                -0.098266                  0.140631
# mYHZ32AyKCmNrfSY5 0      1                -0.008859                  0.060322
# nkPob7gypQi6DtwqS 0      1                -0.027156                  0.050441
# nyj44mrAdH9BGGSnK 0      1                 0.087627                  0.023793
# rtzgQPuxzH7dGbna4 0      1                 0.025760                 -0.017766
# yAmdFLN5XZJ6SxeKL 0      1                 0.047594                  0.155037
# yBcW7BjFe59HDfshF 0      1                 0.006165                  0.007016
#
#                      net spoke PC1  survey 5% similarity  \
# id
# 7c9biMCakuPCxMEXN 0      -0.019286             -0.014927
# 7kcXpJaQqJmx68nYz 0      -0.008215              0.092525
# BfWPcLgXY7dKcAsdX 0       0.027315              0.117082
# BhccgcKQe7bpH7pWi 0       0.049973              0.017871
# EFdcytJKJJAgFebvR 0      -0.004104             -0.255713
# ETYJ4Ru9uE3Fszkkr 0       0.000404             -0.056852
# F6g9NDczqP966pA5m 0      -0.073903              0.060425
# KtFjB6pDKRispFwCs 0       0.022242             -0.258247
# Lj2up2ePZA6WtiK4q 0       0.043147             -0.072689
# MfjKnfErfu8AMLKps 0      -0.039585              0.000816
# RugWRCuQ9MounHF8x 0      -0.001104             -0.110936
# SamzHPveTXj44MS6F 0      -0.027744             -0.077974
# T9KCzCFiibi6W5mnL 0      -0.018670              0.015369
# TCrgRvccdKGHeDvdW 0       0.046220             -0.053835
# W3Pr3tyHAoPsyoZxh 0       0.016768             -0.220923
# Zxhtd5NFdLyNExLtN 0      -0.047254              0.136801
# aS5rH5N5tnRsr3CQQ 0       0.014641             -0.093159
# c2BKscFKSBaujzQHw 0       0.083090              0.147770
# d2N6gipGzAM2B3GPn 0       0.141617              0.090496
# dC7qKt8rhj8W3FFTC 0      -0.015453             -0.009605
# e6Kq4iEPeKDdJ3wyk 0       0.097802              0.024714
# hE8iDmuY7wvbgTTRB 0       0.052154             -0.296748
# hjTbDvCzT2RW9pgm8 0      -0.002076             -0.101527
# ig8z4GCN3uW4nFT54 0       0.135585             -0.073857
# mYHZ32AyKCmNrfSY5 0       0.066622             -0.070980
# nkPob7gypQi6DtwqS 0       0.033999              0.075914
# nyj44mrAdH9BGGSnK 0       0.063531             -0.037253
# rtzgQPuxzH7dGbna4 0      -0.056085              0.022042
# yAmdFLN5XZJ6SxeKL 0       0.044886             -0.081499
# yBcW7BjFe59HDfshF 0       0.046722              0.061132
#
#                      survey 95% similarity  survey PC1
# id
# 7c9biMCakuPCxMEXN 0               0.005513   -0.002486
# 7kcXpJaQqJmx68nYz 0               0.064272   -0.093450
# BfWPcLgXY7dKcAsdX 0               0.178649   -0.021611
# BhccgcKQe7bpH7pWi 0              -0.040406    0.080873
# EFdcytJKJJAgFebvR 0              -0.167763   -0.128511
# ETYJ4Ru9uE3Fszkkr 0              -0.038889   -0.067455
# F6g9NDczqP966pA5m 0               0.068939    0.026623
# KtFjB6pDKRispFwCs 0              -0.132427   -0.040490
# Lj2up2ePZA6WtiK4q 0              -0.163404    0.048950
# MfjKnfErfu8AMLKps 0               0.153220    0.154565
# RugWRCuQ9MounHF8x 0               0.063415   -0.012975
# SamzHPveTXj44MS6F 0              -0.036275    0.093232
# T9KCzCFiibi6W5mnL 0              -0.165261   -0.027793
# TCrgRvccdKGHeDvdW 0              -0.022965    0.029186
# W3Pr3tyHAoPsyoZxh 0              -0.128587   -0.014455
# Zxhtd5NFdLyNExLtN 0               0.006263   -0.001978
# aS5rH5N5tnRsr3CQQ 0              -0.056398    0.110793
# c2BKscFKSBaujzQHw 0               0.118885   -0.049355
# d2N6gipGzAM2B3GPn 0               0.108692    0.095582
# dC7qKt8rhj8W3FFTC 0              -0.052922    0.008657
# e6Kq4iEPeKDdJ3wyk 0               0.079329    0.071308
# hE8iDmuY7wvbgTTRB 0              -0.007779    0.091808
# hjTbDvCzT2RW9pgm8 0              -0.065562    0.050149
# ig8z4GCN3uW4nFT54 0               0.078669    0.175242
# mYHZ32AyKCmNrfSY5 0              -0.110026    0.111172
# nkPob7gypQi6DtwqS 0               0.022761    0.006049
# nyj44mrAdH9BGGSnK 0               0.001722    0.039527
# rtzgQPuxzH7dGbna4 0              -0.002910   -0.047763
# yAmdFLN5XZJ6SxeKL 0              -0.018527    0.047161
# yBcW7BjFe59HDfshF 0               0.143199    0.110000

# %% [markdown]
# ## Bars only plots
#
# This is a bit cleaner, I like it better.

# %%
plt.rcParams.update(rcParamsDefault)
plt.rcParams.update({
    "figure.dpi": 200,
    "figure.facecolor": "white", 
    "savefig.dpi": 150,
    
    "font.family": "sans-serif",
    "font.sans-serif": "Helvetica",
    "font.size": 7,
    
    'ytick.major.size': 0,
    'ytick.color': 'dimgrey',
    'ytick.labelsize': 5,
    'ytick.major.pad': 1.5,
    
    'xtick.major.size': 0,
    'xtick.color': 'dimgrey',
    'xtick.labelsize': 5,
    'xtick.major.pad': 1,
    
    "text.color": "grey",
    "text.usetex": True,
    "hatch.color": "salmon",
    "hatch.linewidth": 5
})


fig = plt.figure(figsize=(3.5, 3.5))

upper_top = .87
lower_top = .4
right_left = .51

fig.patches.extend([plt.Rectangle((0,0.93),0.025,0.025,
                                  fill=True, color='r', alpha=1, zorder=1000,
                                  transform=fig.transFigure, figure=fig)])

plt.figtext(x=.035, y=.93, 
            s='Effect of interdependence above baseline', 
            rotation=0, va='bottom', ha='left', fontsize=6)

fig.patches.extend([plt.Rectangle((right_left, 0.93),0.025,0.025,
                                  fill=False, linestyle='--', linewidth=.8, 
                                  color='dimgrey', alpha=1, zorder=1000,
                                  transform=fig.transFigure, figure=fig)])

plt.figtext(x=right_left+.035, y=0.93, 
            s='Maximum effect of social network structure', 
            rotation=0, va='bottom', ha='left', fontsize=6)


# similarity within camps
ax1 = plt.subplot(2,2,3) 
plt.hlines(0,-.5,1.5, color='grey', linewidth=1)
plt.figtext(x=0, y=lower_top, s='B. Similarity within camps', 
            va='bottom', ha='left', color='k', size=8)

plt.figtext(x=0, y=lower_top-.01, 
            s=r'Change in 95\textsuperscript{th} percentile correlation', 
            rotation=90, va='top', ha='left', fontsize=6)


df = end_of_game.swaplevel().loc['net spoke 95% similarity']

ax1.bar(x=0, 
       height=df.at["('caveman', 'indep')", 'Effect Size'],
       linewidth=.8, linestyle='--',
       facecolor='w',
       edgecolor='dimgrey',
       alpha=1,
       yerr=[[df.at["('caveman', 'indep')", 'Effect Lower Error']], [df.at["('caveman', 'indep')", 'Effect Upper Error']]],
       ecolor="dimgrey", 
       error_kw=dict(lw=.5, ls='--', capsize=1.5, capthick=.5, alpha=1),
)

ax1.bar(x=0, 
       height=df.at["('dodec', 'inter')", 'Effect Size'],
       linewidth=.8,
       color='r',
       alpha=1,
       yerr=[[df.at["('dodec', 'inter')", 'Effect Lower Error']], [df.at["('dodec', 'inter')", 'Effect Upper Error']]],
       ecolor="k", 
       error_kw=dict(lw=.5, capsize=2.5, capthick=.5, alpha=1),
)


df = end_of_game.swaplevel().loc['survey 95% similarity']

ax1.bar(x=1, 
       height=df.at["('caveman', 'indep')", 'Effect Size'],
       linewidth=.8, linestyle='--',
       facecolor='w',
       edgecolor='dimgrey',
       alpha=1,
       yerr=[[df.at["('caveman', 'indep')", 'Effect Lower Error']], [df.at["('caveman', 'indep')", 'Effect Upper Error']]],
       ecolor="dimgrey", 
       error_kw=dict(lw=.5, ls='--', capsize=1.5, capthick=.5, alpha=1),
)

ax1.bar(x=1, 
       height=df.at["('dodec', 'inter')", 'Effect Size'],
       linewidth=.8,
       color='r',
       alpha=1,
       yerr=[[df.at["('dodec', 'inter')", 'Effect Lower Error']], [df.at["('dodec', 'inter')", 'Effect Upper Error']]],
       ecolor="k", 
       error_kw=dict(lw=.5, capsize=2.5, capthick=.5, alpha=1),
)

plt.box(on=False)
ax1.set_xlim(-.5, 1.5)
ax1.set_yticks([-.05, 0, .05, .1, .15])
ax1.set_yticklabels([-.05, 0, .05, .1, .15])
ax1.set_ylim(-.035, .195)
ax1.set_xticks([0,1])
ax1.set_xticklabels(['Behavioral**', 'Self-report'], fontsize=6)


# similarity across camps
ax2 = plt.subplot(2,2,4) 
plt.hlines(0,-.5,1.5, color='grey', linewidth=1)
plt.figtext(x=right_left, y=lower_top, s='C. Difference between camps', va='bottom', color='k', size=8)
plt.figtext(x=right_left, y=lower_top-.01, 
            s=r'Change in 5\textsuperscript{th} percentile correlation', 
            rotation=90, va='top', ha='left', fontsize=6)


df = end_of_game.swaplevel().loc['net spoke 5% similarity']

ax2.bar(x=0, 
       height=df.at["('caveman', 'indep')", 'Effect Size'],
       linewidth=.8, linestyle='--',
       facecolor='w',
       edgecolor='dimgrey',
       alpha=1,
       yerr=[[df.at["('caveman', 'indep')", 'Effect Lower Error']], [df.at["('caveman', 'indep')", 'Effect Upper Error']]],
       ecolor="dimgrey", 
       error_kw=dict(lw=.5, ls='--', capsize=1.5, capthick=.5, alpha=1),
)

ax2.bar(x=0, 
       height=df.at["('dodec', 'inter')", 'Effect Size'],
       linewidth=.8,
       color='r',
       alpha=1,
       yerr=[[df.at["('dodec', 'inter')", 'Effect Lower Error']], [df.at["('dodec', 'inter')", 'Effect Upper Error']]],
       ecolor="k", 
       error_kw=dict(lw=.5, capsize=2.5, capthick=.5, alpha=1),
)



df = end_of_game.swaplevel().loc['survey 5% similarity']

ax2.bar(x=1, 
       height=df.at["('caveman', 'indep')", 'Effect Size'],
       linewidth=.8, linestyle='--',
       facecolor='w',
       edgecolor='dimgrey',
       alpha=1,
       yerr=[[df.at["('caveman', 'indep')", 'Effect Lower Error']], [df.at["('caveman', 'indep')", 'Effect Upper Error']]],
       ecolor="dimgrey", 
       error_kw=dict(lw=.5, ls='--', capsize=1.5, capthick=.5, alpha=1),
)

ax2.bar(x=1, 
       height=df.at["('dodec', 'inter')", 'Effect Size'],
       linewidth=.8,
       color='r',
       alpha=1,
       yerr=[[df.at["('dodec', 'inter')", 'Effect Lower Error']], [df.at["('dodec', 'inter')", 'Effect Upper Error']]],
       ecolor="k", 
       error_kw=dict(lw=.5, capsize=2.5, capthick=.5, alpha=1),
)

plt.box(on=False)
ax2.set_xlim(-.5, 1.5)
ax2.set_yticks([-.1, -.05, 0, .05])
ax2.set_yticklabels([-.1, -.05, 0, .05])
ax2.set_ylim(-.14, -.14+.23)
ax2.set_xticks([0,1])
ax2.set_xticklabels(['Behavioral', 'Self-report*'], fontsize=6)

# PC1
ax3 = plt.subplot(2,2,1) 
plt.figtext(x=.0, y=upper_top, s="A. Alignment along a ``left-right'' axis", va='bottom', color='k', size=8)
plt.figtext(x=0, y=upper_top-.01, 
            #s='(change in \% variance in $1^{st}$ component)', 
            s=r'Change in \% variance in a single axis', 
            rotation=90, va='top', ha='left', fontsize=6)

plt.hlines(0,-.5,1.5, color='grey', linewidth=1)
df = end_of_game.swaplevel().loc['net spoke PC1']

ax3.bar(x=0, 
       height=df.at["('caveman', 'indep')", 'Effect Size'],
       linewidth=.8, linestyle='--',
       facecolor='w',
       edgecolor='dimgrey',
       alpha=1,
       yerr=[[df.at["('caveman', 'indep')", 'Effect Lower Error']], [df.at["('caveman', 'indep')", 'Effect Upper Error']]],
       ecolor="dimgrey", 
       error_kw=dict(lw=.5, ls='--', capsize=1.5, capthick=.5, alpha=1),
)

ax3.bar(x=0, 
       height=df.at["('dodec', 'inter')", 'Effect Size'],
       linewidth=.8,
       color='r',
       alpha=1,
       yerr=[[df.at["('dodec', 'inter')", 'Effect Lower Error']], [df.at["('dodec', 'inter')", 'Effect Upper Error']]],
       ecolor="k", 
       error_kw=dict(lw=.5, capsize=2.5, capthick=.5, alpha=1),
)


df = end_of_game.swaplevel().loc['survey PC1']

ax3.bar(x=1, 
       height=df.at["('caveman', 'indep')", 'Effect Size'],
       linewidth=.8, linestyle='--',
       facecolor='w',
       edgecolor='dimgrey',
       alpha=1,
       yerr=[[df.at["('caveman', 'indep')", 'Effect Lower Error']], [df.at["('caveman', 'indep')", 'Effect Upper Error']]],
       ecolor="dimgrey", 
       error_kw=dict(lw=.5, ls='--', capsize=1.5, capthick=.5, alpha=1),
)

ax3.bar(x=1, 
       height=df.at["('dodec', 'inter')", 'Effect Size'],
       linewidth=.8,
       color='r',
       alpha=1,
       yerr=[[df.at["('dodec', 'inter')", 'Effect Lower Error']], [df.at["('dodec', 'inter')", 'Effect Upper Error']]],
       ecolor="k", 
       error_kw=dict(lw=.5, capsize=2.5, capthick=.5, alpha=1),
)

plt.box(on=False)
ax3.set_xlim(-.5, 1.5)
ax3.set_xticks([0,1])
ax3.set_xticklabels(['Behavioral**', 'Self-report**'], fontsize=6)

ax3.set_yticks([0, .05, .1, .15])
ax3.set_yticklabels(["0\%", "5\%", "10\%", "15\%"])
ax3.set_ylim(-.005, .16)

# networks
ax4 = plt.subplot(2,2,2)
plt.box(on=False)
plt.arrow(.6,.78,0,-.16, 
          length_includes_head=True, width=.002, head_width=.035, facecolor='dimgrey', edgecolor='dimgrey')
ax4.set_xlim(0,1)
ax4.set_ylim(0,1)
ax4.set_xticks([])
ax4.set_yticks([])

dodec = mpimg.imread("../documents/images/network_dodec.png")
ax4a = fig.add_axes([.645, .78, .11, .11])
plt.imshow(dodec)
plt.box(on=False)
ax4a.set_xticks([])
ax4a.set_yticks([])

caveman = mpimg.imread("../documents/images/network_caveman.png")
ax4b = fig.add_axes([.63, .62, .14, .14])
plt.imshow(caveman)
plt.box(on=False)
ax4b.set_xticks([])
ax4b.set_yticks([])

plt.figtext(x=.64+.13, y=.88, s='Minimally polarizing\nsocial network\n(0\% Shared neighbors\nAvg. distance: 2.6 steps)', 
            va='top', ha='left', size=5)

plt.figtext(x=.64+.14, y=.725, s='Maximally polarizing\nsocial network\n(50\% Shared neighbors\nAvg. distance: 4 steps)', 
            va='top', ha='left', size=5)


# annotations
plt.figtext(x=.275, y=upper_top-.045, s='Changing the social network\nfrom the least to most polarizing\nstructures creates an ' r"\textit{a fortiori}" "\ncomparison effect.", 
             va='top', size=5)


plt.figtext(x=.47, y=upper_top-.285, s='The effect of interdependent diffusion is nontrivial\nin comparison to the ' r"\textit{a fortiori} " 'social network effect,\nand so also to that of real-world social networks.', 
             va='top', size=5)


# Title
plt.suptitle('The Effects of Interdependence Found In Experiment', 
             x=0, y=1, 
             ha='left', va='top', fontsize=10, color='k')

plt.tight_layout()
plt.subplots_adjust(left=.08, right=.99, top=upper_top, bottom=.025, wspace=.35, hspace=.35)
plt.savefig('../documents/images/results_small.png', dpi=250)
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:368: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %% [markdown]
# ## Plots with dots
#
# Nature format requires that you show the distribution of the data.

# %%
plt.rcParams.update(rcParamsDefault)
plt.rcParams.update({
    "figure.dpi": 300,
    "figure.facecolor": "white", 
    #"figure.facecolor": "lightyellow",
    
    "savefig.dpi": 300,
    
    "font.family": "sans-serif",
    "font.sans-serif": "Helvetica",
    "font.size": 7,
    
    'ytick.major.size': 0,
    'ytick.color': 'dimgrey',
    'ytick.labelsize': 5,
    'ytick.major.pad': 1.5,
    
    'xtick.major.size': 0,
    'xtick.color': 'dimgrey',
    'xtick.labelsize': 5,
    'xtick.major.pad': 1,
    
    "text.color": "grey",
    "text.usetex": True,
    
    'lines.markeredgecolor': 'auto',
    'lines.markeredgewidth': 0,
    'lines.markerfacecolor': 'firebrick',
    'lines.markersize': 2.5,
    
    #"hatch.color": "salmon",
    #"hatch.linewidth": 5
})
dot_alpha = .4

fig = plt.figure(figsize=(3.5, 3.5))

upper_top = .87
lower_top = .4
right_left = .51


fig.patches.extend([plt.Rectangle((0,0.93),0.025,0.025,
                                  fill=True, color='r', alpha=1, zorder=1000,
                                  transform=fig.transFigure, figure=fig)])

plt.figtext(x=.035, y=.93, 
            s='Effect of interdependence above baseline', 
            rotation=0, va='bottom', ha='left', fontsize=6)

fig.patches.extend([plt.Rectangle((right_left, 0.93),0.025,0.025,
                                  fill=False, linestyle='--', linewidth=.8, 
                                  color='dimgrey', alpha=1, zorder=1000,
                                  transform=fig.transFigure, figure=fig)])

plt.figtext(x=right_left+.035, y=0.93, 
            s='Maximum effect of social network structure', 
            rotation=0, va='bottom', ha='left', fontsize=6)


# similarity within camps, behavioral
ax1 = plt.subplot(2,2,3) 
plt.hlines(0,-.5,1.5, color='grey', linewidth=1)
plt.figtext(x=0, y=lower_top, s='B. Similarity within camps', 
            va='bottom', ha='left', color='k', size=8)
# plt.figtext(x=0, y=lower_top-.01, 
#             s='Within-camp similarity', 
#             rotation=90, va='top', ha='left', fontsize=7)
# plt.figtext(x=.025, y=lower_top-.01, 
#             s=r'(change in 95\textsuperscript{th} percentile correlation)', 
#             rotation=90, va='top', ha='left', fontsize=5)

plt.figtext(x=0, y=lower_top-.01, 
            s=r'Change in 95\textsuperscript{th} percentile correlation', 
            rotation=90, va='top', ha='left', fontsize=6)


df = end_of_game.swaplevel().loc['net spoke 95% similarity']

# plt.figtext(x=x0, y=.96, 
#             s='Within-camp similarity\n($95^{th}$ percentile correlation)', 
#             rotation=90, va='top', ha='center')


ax1.bar(x=0, 
       height=df.at["('caveman', 'indep')", 'Effect Size'],
       linewidth=.8, linestyle='--',
       facecolor='w',
       edgecolor='dimgrey',
       alpha=1,
       yerr=[[df.at["('caveman', 'indep')", 'Effect Lower Error']], [df.at["('caveman', 'indep')", 'Effect Upper Error']]],
       ecolor="dimgrey", 
       error_kw=dict(lw=.5, ls='--', capsize=1.5, capthick=.5, alpha=1),
)

ax1.bar(x=0, 
       height=df.at["('dodec', 'inter')", 'Effect Size'],
       linewidth=.8,
       color='r',
       alpha=1,
       yerr=[[df.at["('dodec', 'inter')", 'Effect Lower Error']], [df.at["('dodec', 'inter')", 'Effect Upper Error']]],
       ecolor="k", 
       error_kw=dict(lw=.5, capsize=2.5, capthick=.5, alpha=1),
)

ax1.plot(np.random.normal(scale=.05, size=len(dots)), dots['net spoke 95% similarity'], '.', alpha=dot_alpha)


df = end_of_game.swaplevel().loc['survey 95% similarity']

ax1.bar(x=1, 
       height=df.at["('caveman', 'indep')", 'Effect Size'],
       linewidth=.8, linestyle='--',
       facecolor='w',
       edgecolor='dimgrey',
       alpha=1,
       yerr=[[df.at["('caveman', 'indep')", 'Effect Lower Error']], [df.at["('caveman', 'indep')", 'Effect Upper Error']]],
       ecolor="dimgrey", 
       error_kw=dict(lw=.5, ls='--', capsize=1.5, capthick=.5, alpha=1),
)

ax1.bar(x=1, 
       height=df.at["('dodec', 'inter')", 'Effect Size'],
       linewidth=.8,
       color='r',
       alpha=1,
       yerr=[[df.at["('dodec', 'inter')", 'Effect Lower Error']], [df.at["('dodec', 'inter')", 'Effect Upper Error']]],
       ecolor="k", 
       error_kw=dict(lw=.5, capsize=2.5, capthick=.5, alpha=1),
)

ax1.plot(np.random.normal(loc=1, scale=.05, size=len(dots)), dots['survey 95% similarity'], '.', alpha=dot_alpha)

plt.box(on=False)
ax1.set_xlim(-.5, 1.5)
ax1.set_yticks([-.3, -.2, -.1,  0,  .1, .2])
ax1.set_yticklabels([-.3, -.2,  -.1,  0,  .1, .2])
ax1.set_ylim(-.32, .2)
ax1.set_xticks([0,1])
ax1.set_xticklabels(['Behavioral**', 'Self-report'], fontsize=6)

# similarity across camps
ax2 = plt.subplot(2,2,4) 
plt.hlines(0,-.5,1.5, color='grey', linewidth=1)
plt.figtext(x=right_left, y=lower_top, s='C. Difference between camps', va='bottom', color='k', size=8)
# plt.figtext(x=right_left, y=lower_top-.01, 
#             s='Across-camp similarity', 
#             rotation=90, va='top', ha='left', fontsize=7)
# plt.figtext(x=right_left+.025, y=lower_top-.01, 
#             s=r'(change in 5\textsuperscript{th} percentile correlation)', 
#             rotation=90, va='top', ha='left', fontsize=5)

plt.figtext(x=right_left, y=lower_top-.01, 
            s=r'Change in 5\textsuperscript{th} percentile correlation', 
            rotation=90, va='top', ha='left', fontsize=6)


df = end_of_game.swaplevel().loc['net spoke 5% similarity']

ax2.bar(x=0, 
       height=df.at["('caveman', 'indep')", 'Effect Size'],
       linewidth=.8, linestyle='--',
       facecolor='w',
       edgecolor='dimgrey',
       alpha=1,
       yerr=[[df.at["('caveman', 'indep')", 'Effect Lower Error']], [df.at["('caveman', 'indep')", 'Effect Upper Error']]],
       ecolor="dimgrey", 
       error_kw=dict(lw=.5, ls='--', capsize=1.5, capthick=.5, alpha=1),
)

ax2.bar(x=0, 
       height=df.at["('dodec', 'inter')", 'Effect Size'],
       linewidth=.8,
       color='r',
       alpha=1,
       yerr=[[df.at["('dodec', 'inter')", 'Effect Lower Error']], [df.at["('dodec', 'inter')", 'Effect Upper Error']]],
       ecolor="k", 
       error_kw=dict(lw=.5, capsize=2.5, capthick=.5, alpha=1),
)

ax2.plot(np.random.normal(loc=0, scale=.05, size=len(dots)), dots['net spoke 5% similarity'], '.', alpha=dot_alpha)

df = end_of_game.swaplevel().loc['survey 5% similarity']

ax2.bar(x=1, 
       height=df.at["('caveman', 'indep')", 'Effect Size'],
       linewidth=.8, linestyle='--',
       facecolor='w',
       edgecolor='dimgrey',
       alpha=1,
       yerr=[[df.at["('caveman', 'indep')", 'Effect Lower Error']], [df.at["('caveman', 'indep')", 'Effect Upper Error']]],
       ecolor="dimgrey", 
       error_kw=dict(lw=.5, ls='--', capsize=1.5, capthick=.5, alpha=1),
)

ax2.bar(x=1, 
       height=df.at["('dodec', 'inter')", 'Effect Size'],
       linewidth=.8,
       color='r',
       alpha=1,
       yerr=[[df.at["('dodec', 'inter')", 'Effect Lower Error']], [df.at["('dodec', 'inter')", 'Effect Upper Error']]],
       ecolor="k", 
       error_kw=dict(lw=.5, capsize=2.5, capthick=.5, alpha=1),
)

ax2.plot(np.random.normal(loc=1, scale=.05, size=len(dots)), dots['survey 5% similarity'], '.', alpha=dot_alpha)

plt.box(on=False)
ax2.set_xlim(-.5, 1.5)
ax2.set_yticks([-.3, -.2, -.1,  0,  .1, .2])
ax2.set_yticklabels([-.3, -.2,  -.1,  0,  .1, .2])
ax2.set_ylim(-.32, .2)
ax2.set_xticks([0,1])
ax2.set_xticklabels(['Behavioral', 'Self-report*'], fontsize=6)

# PC1
ax3 = plt.subplot(2,2,1) 
plt.figtext(x=.0, y=upper_top, s="A. Alignment along a ``left-right'' axis", va='bottom', color='k', size=8)
plt.figtext(x=0, y=upper_top-.01,  
            s=r'Change in \% variance in a single axis', 
            rotation=90, va='top', ha='left', fontsize=6)

plt.hlines(0,-.5,1.5, color='grey', linewidth=1)
df = end_of_game.swaplevel().loc['net spoke PC1']

ax3.bar(x=0, 
       height=df.at["('caveman', 'indep')", 'Effect Size'],
       linewidth=.8, linestyle='--',
       facecolor='w',
       edgecolor='dimgrey',
       alpha=1,
       yerr=[[df.at["('caveman', 'indep')", 'Effect Lower Error']], [df.at["('caveman', 'indep')", 'Effect Upper Error']]],
       ecolor="dimgrey", 
       error_kw=dict(lw=.5, ls='--', capsize=1.5, capthick=.5, alpha=1),
)

ax3.bar(x=0, 
       height=df.at["('dodec', 'inter')", 'Effect Size'],
       linewidth=.8,
       color='r',
       alpha=1,
       yerr=[[df.at["('dodec', 'inter')", 'Effect Lower Error']], [df.at["('dodec', 'inter')", 'Effect Upper Error']]],
       ecolor="k", 
       error_kw=dict(lw=.5, capsize=2.5, capthick=.5, alpha=1),
)

ax3.plot(np.random.normal(loc=0, scale=.05, size=len(dots)), dots['net spoke PC1'], '.', alpha=dot_alpha)


df = end_of_game.swaplevel().loc['survey PC1']

ax3.bar(x=1, 
       height=df.at["('caveman', 'indep')", 'Effect Size'],
       linewidth=.8, linestyle='--',
       facecolor='w',
       edgecolor='dimgrey',
       alpha=1,
       yerr=[[df.at["('caveman', 'indep')", 'Effect Lower Error']], [df.at["('caveman', 'indep')", 'Effect Upper Error']]],
       ecolor="dimgrey", 
       error_kw=dict(lw=.5, ls='--', capsize=1.5, capthick=.5, alpha=1),
)

ax3.bar(x=1, 
       height=df.at["('dodec', 'inter')", 'Effect Size'],
       linewidth=.8,
       color='r',
       alpha=1,
       yerr=[[df.at["('dodec', 'inter')", 'Effect Lower Error']], [df.at["('dodec', 'inter')", 'Effect Upper Error']]],
       ecolor="k", 
       error_kw=dict(lw=.5, capsize=2.5, capthick=.5, alpha=1),
)

ax3.plot(np.random.normal(loc=1, scale=.05, size=len(dots)), dots['survey PC1'], '.', alpha=dot_alpha)


plt.box(on=False)
ax3.set_xlim(-.5, 1.5)
ax3.set_xticks([0,1])
ax3.set_xticklabels(['Behavioral**', 'Self-report**'], fontsize=6)

ax3.set_yticks([-.15, -.1, -.05, 0, .05, .1, .15])
ax3.set_yticklabels(["-15%", "-10\%", "-5\%", "0\%", "5\%", "10\%", "15\%"])
ax3.set_ylim(-.13, .16)


# confidence and consensus
ax4 = plt.subplot(2,2,2)
plt.box(on=False)
plt.arrow(.14,.22,.25,0, 
          length_includes_head=True, width=.002, head_width=.035, facecolor='dimgrey', edgecolor='dimgrey')
ax4.set_xlim(0,1)
ax4.set_ylim(0,1)
ax4.set_xticks([])
ax4.set_yticks([])

dodec = mpimg.imread("../documents/images/network_dodec.png")
caveman = mpimg.imread("../documents/images/network_caveman.png")


ax4a = fig.add_axes([.54, .54, .1, .1])
plt.imshow(dodec)
plt.box(on=False)
ax4a.set_xticks([])
ax4a.set_yticks([])

ax4b = fig.add_axes([.77, .53, .12, .12])
plt.imshow(caveman)
plt.box(on=False)
ax4b.set_xticks([])
ax4b.set_yticks([])

plt.figtext(x=.54+.1/2, y=.525, s='Minimally polarizing\nsocial network',#\n(0\% Shared neighbors\nAvg. distance: 2.6 steps)', 
            va='top', ha='center', size=5)

plt.figtext(x=.77+.12/2, y=.525, s='Maximally polarizing\nsocial network',#\n(50\% Shared neighbors\nAvg. distance: 4 steps)', 
            va='top', ha='center', size=5)


plt.figtext(x=.27, y=upper_top-.013,#x=.47, y=upper_top-.042, 
            s='Changing the social network from the least to most polarizing\nstructures creates an ' r"\textit{a fortiori}" " comparison effect.", 
            va='top', size=5)

# plt.figtext(x=.27, y=upper_top-.01,#x=.47, y=upper_top-.042, 
#             s='Changing the social network from the least to\nmost polarizing structures creates an ' r"\textit{a fortiori}" "\ncomparison effect.", 
#             va='top', size=5)


plt.figtext(x=.46, y=upper_top-.13,#x=.47, y=upper_top-.14, 
            s='The effect of interdependent diffusion is nontrivial in\ncomparison to the ' r"\textit{a fortiori} " 'social network effect,\nand so also to that of real-world social networks.', 
            va='top', size=5)

# fig.patches.extend([plt.Rectangle((.55, upper_top),0.0375,-0.07,
#                                   fill=False, linestyle='--', linewidth=.8, 
#                                   color='dimgrey', alpha=1, zorder=1000,
#                                   transform=fig.transFigure, figure=fig)])




plt.suptitle('The Effects of Interdependence Found In Experiment', 
             x=0, y=1, 
             ha='left', va='top', fontsize=10, color='k')

plt.tight_layout()
plt.subplots_adjust(left=.08, right=.99, top=upper_top, bottom=.025, wspace=.35, hspace=.35)
plt.savefig('../documents/images/results_small_dots.png', dpi=300)
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:376: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
