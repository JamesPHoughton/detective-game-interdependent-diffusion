# %% [markdown]
# # Review inputs
#
# This `Python 3` notebook checks the setup for each of the games in the experiment,
# to make sure that the social network, clues, and clue assignments reflect
# the desired experimental condition.

# %%
# %pylab inline
import networkx as nx
import json
import numpy as np
import pandas as pd
from collections import Counter

import language_check
import re
import string
from collections import Counter
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Import and describe Experiment

# %%
experiment_filepath = "games/prereg_20200702_161449.json"

with open(experiment_filepath, 'r') as f:
    experiment = json.load(f)
    
describe = {k: experiment[k] for k in set(experiment.keys())-{"games"}}
describe['n_games'] = len(experiment["games"])
describe
# Out:
# {'replications': 40,
#  'deg': 3,
#  'n_beliefs': 4,
#  'n_players': 20,
#  'p_broken_list': 'matched inter/indep pair',
#  'experiment_setup_name': 'prereg_20200702_161449',
#  'n_games': 80}

# %%
for game_id, game in experiment['games'].items():
    print(game_id)
# Out:
# block_0_dodec_prereg_20200702_161449
# block_0_caveman_prereg_20200702_161449
# block_1_dodec_prereg_20200702_161449
# block_1_caveman_prereg_20200702_161449
# block_2_dodec_prereg_20200702_161449
# block_2_caveman_prereg_20200702_161449
# block_3_dodec_prereg_20200702_161449
# block_3_caveman_prereg_20200702_161449
# block_4_dodec_prereg_20200702_161449
# block_4_caveman_prereg_20200702_161449
# block_5_dodec_prereg_20200702_161449
# block_5_caveman_prereg_20200702_161449
# block_6_dodec_prereg_20200702_161449
# block_6_caveman_prereg_20200702_161449
# block_7_dodec_prereg_20200702_161449
# block_7_caveman_prereg_20200702_161449
# block_8_dodec_prereg_20200702_161449
# block_8_caveman_prereg_20200702_161449
# block_9_dodec_prereg_20200702_161449
# block_9_caveman_prereg_20200702_161449
# block_10_dodec_prereg_20200702_161449
# block_10_caveman_prereg_20200702_161449
# block_11_dodec_prereg_20200702_161449
# block_11_caveman_prereg_20200702_161449
# block_12_dodec_prereg_20200702_161449
# block_12_caveman_prereg_20200702_161449
# block_13_dodec_prereg_20200702_161449
# block_13_caveman_prereg_20200702_161449
# block_14_dodec_prereg_20200702_161449
# block_14_caveman_prereg_20200702_161449
# block_15_dodec_prereg_20200702_161449
# block_15_caveman_prereg_20200702_161449
# block_16_dodec_prereg_20200702_161449
# block_16_caveman_prereg_20200702_161449
# block_17_dodec_prereg_20200702_161449
# block_17_caveman_prereg_20200702_161449
# block_18_dodec_prereg_20200702_161449
# block_18_caveman_prereg_20200702_161449
# block_19_dodec_prereg_20200702_161449
# block_19_caveman_prereg_20200702_161449
# block_20_dodec_prereg_20200702_161449
# block_20_caveman_prereg_20200702_161449
# block_21_dodec_prereg_20200702_161449
# block_21_caveman_prereg_20200702_161449
# block_22_dodec_prereg_20200702_161449
# block_22_caveman_prereg_20200702_161449
# block_23_dodec_prereg_20200702_161449
# block_23_caveman_prereg_20200702_161449
# block_24_dodec_prereg_20200702_161449
# block_24_caveman_prereg_20200702_161449
# block_25_dodec_prereg_20200702_161449
# block_25_caveman_prereg_20200702_161449
# block_26_dodec_prereg_20200702_161449
# block_26_caveman_prereg_20200702_161449
# block_27_dodec_prereg_20200702_161449
# block_27_caveman_prereg_20200702_161449
# block_28_dodec_prereg_20200702_161449
# block_28_caveman_prereg_20200702_161449
# block_29_dodec_prereg_20200702_161449
# block_29_caveman_prereg_20200702_161449
# block_30_dodec_prereg_20200702_161449
# block_30_caveman_prereg_20200702_161449
# block_31_dodec_prereg_20200702_161449
# block_31_caveman_prereg_20200702_161449
# block_32_dodec_prereg_20200702_161449
# block_32_caveman_prereg_20200702_161449
# block_33_dodec_prereg_20200702_161449
# block_33_caveman_prereg_20200702_161449
# block_34_dodec_prereg_20200702_161449
# block_34_caveman_prereg_20200702_161449
# block_35_dodec_prereg_20200702_161449
# block_35_caveman_prereg_20200702_161449
# block_36_dodec_prereg_20200702_161449
# block_36_caveman_prereg_20200702_161449
# block_37_dodec_prereg_20200702_161449
# block_37_caveman_prereg_20200702_161449
# block_38_dodec_prereg_20200702_161449
# block_38_caveman_prereg_20200702_161449
# block_39_dodec_prereg_20200702_161449
# block_39_caveman_prereg_20200702_161449

# %% [markdown]
# ## check network structure

# %%
for game_id, game in experiment['games'].items():
    g = nx.from_dict_of_lists(game['neighbors'])
    #nx.draw_networkx(g)
    
    # check that each panel has two components
    assert(nx.number_connected_components(g)==2)
    
    # check that each component has nodes of the same names
    c1, c2 = [g.subgraph(c) for c in nx.connected_components(g)]
    assert(set([n[1:] for n in c1.nodes()]) == set([n[1:] for n in c2.nodes()]))
    
    # check that each component has the right number of nodes
    assert(nx.number_of_nodes(c1)==describe['n_players'])
    assert(nx.number_of_nodes(c2)==describe['n_players'])
        
    # check that each node in each component has matching neighbors
    for n in c1:
        n2 = 't'+n[1:] if n[0] == 'c' else 'c'+n[1:]
        assert(set([nb[1:] for nb in c1.neighbors(n)]) == set([nb[1:] for nb in c2.neighbors(n2)]))

    # check that each node has the number of neighbors listed in the game heading
    assert(all([v== describe['deg'] for k, v in g.degree()]))
    
print('pass')
# Out:
# pass

# %%
# spot check
game_id = list(experiment['games'].keys())[0]
game = experiment['games'][game_id]
g = nx.from_dict_of_lists(game['neighbors'])
nx.draw_networkx(g)
game_id
# Out:
# 'block_0_dodec_prereg_20200702_161449'

# %%
game_id = list(experiment['games'].keys())[1]
game = experiment['games'][game_id]
g = nx.from_dict_of_lists(game['neighbors'])
nx.draw_networkx(g)
game_id
# Out:
# 'block_0_caveman_prereg_20200702_161449'

# %% [markdown]
# ## check clue structure

# %%
tool = language_check.LanguageTool('en-US')
err_counter = Counter()
err_examples = {}

for game_id, game in experiment['games'].items():
    
    for clue_id, clue in game['clues'].items():
        # check that each clue is well formatted        
        assert(len(clue['nodes'])==2)
        assert(all([len(re.sub(r"\s+", "", node, flags=re.UNICODE))>=2  # remove whitespace
                    for node in clue['nodes']]))  # each node has at least two non-whitespace chars
        assert(all([re.sub(r'\{.*\}', '', node.lower()) in clue['content'].lower()  # allow template nodes
                    for node in clue['nodes']]))  # each node present in clue string
        assert(clue['content'].endswith('.'))
        assert(clue['content'][0].isupper())
        
        # check for language errors
        errs = tool.check(clue['content'])
        if(errs):
            for err in errs:
                key = err.locqualityissuetype + ': "' + err.context[err.contextoffset:err.contextoffset+err.errorlength] +'"'
                err_counter[key]+=1
                err_examples[key] = err.context
        
    # check that clues connected to the stolen object or crime scene are identical between trmt and ctrl
    for clue_id, clue in game['clues'].items():
        if (clue_id.startswith('t') and 
            ('_1_' in clue_id or '_2_' in clue_id)):
            control_clue = game['clues']['c'+clue_id.lstrip('t')]
            assert clue['content'] == control_clue['content']

    # check that clue graph is complete for treatment case
    cgt = nx.from_edgelist([
        clue['nodes'] for clue_id, clue in game['clues'].items() if clue_id.startswith('t')
    ])
    assert(all([v == cgt.number_of_nodes()-1 for k, v in cgt.degree()]))

    # check that clue graph has correct degree distribution for control case
    cgc = nx.from_edgelist([
        clue['nodes'] for clue_id, clue in game['clues'].items() if clue_id.startswith('c')
    ])
    assert(Counter([v for k, v in cgc.degree()]) == {12:2, 7:11, 1:55})
    #if not Counter([v for k, v in cgc.degree()]) == {12:2, 7:11, 1:55}:
    #    print([(k,v) for k, v in cgc.degree() if v not in [12, 7, 1]], '\n')
    
print('pass')
    
for key, count in err_counter.most_common():
    print(count, key, err_examples[key])
# Out:
# pass
# 336 misspelling: "Dalhoff" A silver BMW was seen leaving the Dalhoff Estate.
# 304 misspelling: "Bennet" Bennet has an expensive drug habit.
# 240 misspelling: "Asper" ...A yellow box truck was seen leaving the Asper Casino.
# 240 misspelling: "Danforth" ...Chevrolet Corvette was seen leaving the Danforth Hotel.
# 228 misspelling: "Yaris" A blue Toyota Yaris was found with damaged suspension.
# 228 misspelling: "Jetta" A silver VW Jetta was recently purchased at an estate sal...
# 192 misspelling: "Kensington" A blue Toyota Yaris was seen leaving Kensington House.
# 192 misspelling: "Kentwood" ...Chevrolet Corvette was seen leaving the Kentwood Mansion.
# 190 misspelling: "grey-haired" ...lice are interviewing witnesses about a grey-haired man.
# 160 grammar: "wearing" Someone wearing a motorcycle helmet was seen on securit...
# 144 misspelling: "Daly" A silver BMW was seen leaving the Daly Auction House.
# 48 misspelling: "Darrowby" A black Hummer was seen leaving the Darrowby Country Club.
# 30 grammar: "sleeping" A silver BMW was reported with someone sleeping in the back seat.
# 28 misspelling: "Ponzi" ...ds has a prior conviction for running a Ponzi scam.

# %% [markdown]
# ## manually spot check a single game's clues

# %%
game = experiment['games'][np.random.choice(list(experiment['games'].keys()))] # choose a random game
for clue_id, clue in game['clues'].items():
    if clue_id.startswith('t'):
        control_clue = game['clues']['c'+clue_id.lstrip('t')]
        if '_1_' in clue_id or '_2_' in clue_id:
            print(clue['content'].center(110))
        else:
            print(clue['content'].rjust(55), '|', control_clue['content'])
# Out:
#                             The diamond was kept in a case at the Dalhoff Estate.
#                                     Bennet was seen at the Dalhoff Estate.
#                                     Wagner was seen at the Dalhoff Estate.
#                                    Stevens was seen at the Dalhoff Estate.
#                         A person wearing a black scarf was seen at the Dalhoff Estate.
#                      A person wearing a motorcycle helmet was seen at the Dalhoff Estate.
#                                  A short man was seen at the Dalhoff Estate.
#                               A pot-bellied man was seen at the Dalhoff Estate.
#                        Evidence at the Dalhoff Estate indicates the use of a blowtorch.
#                         Evidence at the Dalhoff Estate indicates the use of a hacksaw.
#                             A blue Honda Fit was seen leaving the Dalhoff Estate.
#                            A white Ford Fusion was seen leaving the Dalhoff Estate.
#                                       Bennet knew all about the diamond.
#                                       Wagner knew all about the diamond.
#                                      Stevens knew all about the diamond.
#                     A person wearing a black scarf had been seen lurking near the diamond.
#                  A person wearing a motorcycle helmet had been seen lurking near the diamond.
#                                 A short man had been lurking near the diamond.
#                              A pot-bellied man had been lurking near the diamond.
#                       The case for the diamond might have been opened using a blowtorch.
#                        The case for the diamond might have been opened using a hacksaw.
#                          A witness thought they saw the diamond in a blue Honda Fit.
#                         A witness thought they saw the diamond in a white Ford Fusion.
#                           Wagner hangs out with Bennet. | Wagner wrote a revolutionary manifesto.
#                          Bennet hangs out with Stevens. | Bennet has a gambling addiction.
#                 Bennet was known to wear a black scarf. | A black scarf was found with a home-made electronic device.
#           Bennet was known to wear a motorcycle helmet. | Bennet is in their early 30's.
#                    Bennet was described as a short man. | Private security companies have been warned to... a short man.
#              Bennet was described as a pot-bellied man. | Bennet has a tattoo of a flower.
#                  Bennet had been seen with a blowtorch. | A blowtorch was found wrapped in tape to make it quieter.
#                    Bennet had been seen with a hacksaw. | Bennet has a prior conviction for arson.
#                           Bennet owns a blue Honda Fit. | A blue Honda Fit was ticketed for driving without headlights.
#                        Bennet owns a white Ford Fusion. | Bennet worked for an alarm company.
#                          Stevens hangs out with Wagner. | Stevens has a tattoo of a dog.
#                 Wagner was known to wear a black scarf. | Wagner has a tattoo of a heart.
#           Wagner was known to wear a motorcycle helmet. | A policeman saw someone in a motorcycle helmet pacing back and forth.
#                    Wagner was described as a short man. | Wagner is 37 years old.
#              Wagner was described as a pot-bellied man. | A pot-bellied man was reported vandalizing a vending machine.
#                  Wagner had been seen with a blowtorch. | Wagner has a prior conviction for identity theft.
#                    Wagner had been seen with a hacksaw. | An FBI agent found a hacksaw buried in debris.
#                           Wagner owns a blue Honda Fit. | Wagner has worked as an armored car driver.
#                        Wagner owns a white Ford Fusion. | A white Ford Fusion was reported driving after midnight.
#                Stevens was known to wear a black scarf. | A policeman saw someone in a black scarf getting into a taxi.
#          Stevens was known to wear a motorcycle helmet. | Stevens is in their late 20's.
#                   Stevens was described as a short man. | A short man was reported waiting in a dark alley.
#             Stevens was described as a pot-bellied man. | Stevens has paid hush-money to a former lover.
#                 Stevens had been seen with a blowtorch. | A forensics report contained a blowtorch showing signs of misuse.
#                   Stevens had been seen with a hacksaw. | Stevens has a prior conviction for drug distribution.
#                          Stevens owns a blue Honda Fit. | A blue Honda Fit was reported with someone sleeping in the back seat.
#                       Stevens owns a white Ford Fusion. | Stevens installs security systems.
#       A black scarf was found with a motorcycle helmet. | A motorcycle helmet was found with an envelope containing GPS coordinates.
#             A short man was seen wearing a black scarf. | Someone wearing a black scarf was seen on security footage on the golf course.
#       A pot-bellied man was seen wearing a black scarf. | A pot-bellied man was forcibly removed from a restaurant.
#               A black scarf was found with a blowtorch. | A black scarf was discovered by theater staff cleaning up after a movie.
#                 A black scarf was found with a hacksaw. | A hacksaw was found wrapped in newspaper.
#            A black scarf was found in a blue Honda Fit. | Forensics identified a black scarf cut into pieces.
#         A black scarf was found in a white Ford Fusion. | An officer identified a white Ford Fusion at a massage parlor.
#       A short man was seen wearing a motorcycle helmet. | A short man was treated for minor burns.
# A pot-bellied man was seen wearing a motorcycle helmet. | Someone wearing a motorcycle helmet was seen on security footage at a campsite.
#         A motorcycle helmet was found with a blowtorch. | A blowtorch could be used to open an upper-story window.
#           A motorcycle helmet was found with a hacksaw. | A motorcycle helmet was discovered by a store worker breaking down cardboard boxes.
#      A motorcycle helmet was found in a blue Honda Fit. | An officer identified a blue Honda Fit at a laundromat.
#   A motorcycle helmet was found in a white Ford Fusion. | Forensics identified a motorcycle helmet with frayed edges.
#            A pot-bellied man was seen with a short man. | Law enforcement is seeking a pot-bellied man.
#                  A short man was seen with a blowtorch. | A constable noticed a short man on Chestnut Street.
#                    A short man was seen with a hacksaw. | A forensics report contained a hacksaw with minor damage.
#          A short man was seen driving a blue Honda Fit. | A short man was forcibly removed from a public library.
#       A short man was seen driving a white Ford Fusion. | A white Ford Fusion was ticketed for illegal parking.
#            A pot-bellied man was seen with a blowtorch. | A blowtorch leaves distinctive marks if used carelessly.
#              A pot-bellied man was seen with a hacksaw. | A pot-bellied man was treated for a drug overdose.
#    A pot-bellied man was seen driving a blue Honda Fit. | A blue Honda Fit was recently purchased at a police auction.
# A pot-bellied man was seen driving a white Ford Fusion. | A constable noticed a pot-bellied man on Ninth Avenue.
#                   A blowtorch was found with a hacksaw. | A hacksaw could be used to disassemble an alarm panel.
#              A blowtorch was found in a blue Honda Fit. | An FBI agent found a blowtorch in a garage.
#           A blowtorch was found in a white Ford Fusion. | A white Ford Fusion was found with a broken headlight.
#                A hacksaw was found in a blue Honda Fit. | A blue Honda Fit was found with the airbags deployed.
#             A hacksaw was found in a white Ford Fusion. | A hacksaw was shown in news coverage of another burglary.
#    A white Ford Fusion was found near a blue Honda Fit. | A white Ford Fusion was recently purchased in a wholesale auction.

# %%
# check the ensemble of games to make sure that no particular clue elements have undue weight
element_counter = Counter()
for game_id, game in experiment['games'].items():
    nodes = set()
    for clue_id, clue in game['clues'].items():
        for node in clue['nodes']:
            nodes.add(node)
    for node in nodes:
        element_counter[node] += 1
            
plt.figure(figsize=(6,40))
plt.barh(range(len(element_counter)), element_counter.values())
plt.yticks(range(len(element_counter)), element_counter.keys());

# %%
plt.hist(element_counter.values());

# %% [markdown]
# ## check clue/belief assignments

# %%
for game_id, game in experiment['games'].items():
    belief_list = pd.Series([bf for n in game['beliefs'] for bf in game['beliefs'][n]])
    belief_counts = belief_list.value_counts()
    
    # check that each belief shows up exactly once, apart from clue_1_2, which is present 3 times
    assert(belief_counts['cclue_1_2'] == 3)
    assert(belief_counts['tclue_1_2'] == 3)
    assert(all([v==1 for b, v in belief_counts.iteritems() if b not in ['cclue_1_2', 'tclue_1_2']]))
    
    # check that each player has 4 beliefs
    assert(all([len(v)==4 for k,v in game['beliefs'].items()]))

    # check that control positions have beliefs that match their corresponding treatment positions
    for pos, bs in game['beliefs'].items():
        if pos.startswith('t'):
            control_bs = game['beliefs']['c'+pos.lstrip('t')]
            assert set([b[1:] for b in bs]) == set([cb[1:] for cb in control_bs])

print('pass')
# Out:
# pass

# %% [markdown]
# ## visually spot-check the relationships between clues

# %%
random_game_id = np.random.choice(list(experiment['games'].keys()))
game = experiment['games'][random_game_id]
#plt.figure(figsize=(10,10))
cg = nx.from_edgelist([n['nodes'] for cid, n in game['clues'].items() if cid[0]=='t'])  # clue graph
center_nodes = [game['nodes']['CrimeScene_1'], game['nodes']['StolenObject_1']]
center = nx.from_edgelist(cg.edges(center_nodes))
cg.remove_edges_from(center.edges())
cg.remove_nodes_from(center_nodes)

pos = nx.spring_layout(center)

theta = {key: np.arctan2(val[1], val[0]) * 180/np.pi if key not in center_nodes else 0 
         for key, val in pos.items() }

plt.figure(figsize=(8,8))
nx.draw_networkx_nodes(center, pos=pos, alpha=.5)
labels = nx.draw_networkx_labels(center, pos=pos, font_size=12, ha='left')

for key,t in labels.items():
    if key not in center_nodes:
        if 90 < theta[key] or theta[key] < -90 :
            angle = 180 + theta[key]
            t.set_ha('right')
        else:
            angle = theta[key]
            t.set_ha('left')
        t.set_va('center')
        t.set_rotation(angle)
        t.set_rotation_mode('anchor')
nx.draw_networkx_edges(cg, pos=pos, alpha=.2)
nx.draw_networkx_edges(center, pos=pos, alpha=.4)
plt.box(False)
a=3
plt.xlim(-a,a)
plt.ylim(-a,a)

# save locations with clues for later
clue_pos = {}
for i, n in game['clues'].items():
    if i[0] == 't':
        clue_pos[i[1:]] = np.array([pos[n['nodes'][0]], pos[n['nodes'][1]]])
    
centroids = {k: np.mean(v, axis=0) for k, v in clue_pos.items()}
lengths = {k: sqrt(np.sum((v[1]-v[0])**2)) for k, v in clue_pos.items()}

# %%
ccg = nx.from_edgelist([n['nodes'] for cid, n in game['clues'].items() if cid[0]=='c'])  # control clue graph

# group by shell
center_nodes = [game['nodes']['CrimeScene_1'], game['nodes']['StolenObject_1']]
center = nx.from_edgelist(ccg.edges(center_nodes))
shell_1_nodes = list(set(center.nodes()) - set(center_nodes))
shell_2_nodes = [nb for n in shell_1_nodes for nb in ccg.neighbors(n) if nb not in center_nodes]

rot_n = 2  # rotate n (helps align the outer shell with the middle shell)
shell_2_nodes = shell_2_nodes[rot_n:] + shell_2_nodes[:rot_n]

# positions for nodes
pos = nx.shell_layout(ccg, [center_nodes, shell_1_nodes, shell_2_nodes], scale=1.3)
pos = nx.spring_layout(ccg, pos=pos, fixed=center_nodes+shell_1_nodes, 
                       iterations=1, k=1/sqrt(70))

def rotate(x, rotation=0):
    length = sqrt(x[0]**2 + x[1]**2)
    angle = np.arctan2(x[0], x[1])
    new_angle = angle+rotation
    return [length*cos(new_angle), length*sin(new_angle)]
pos = {k:rotate(v, -0.25) for k, v in pos.items()}

theta = {key: np.arctan2(val[1], val[0]) * 180/np.pi if key in shell_2_nodes else 0 
         for key, val in pos.items() }

plt.figure(figsize=(10,10), dpi=150)
nx.draw_networkx_nodes(ccg, pos=pos, alpha=.4, node_size=70)
nx.draw_networkx_edges(ccg, pos=pos, alpha=.2)

labels = nx.draw_networkx_labels(ccg, pos=pos, font_size=7, ha='left')

for key,t in labels.items():
    if key in shell_2_nodes:
        if 90 < theta[key] or theta[key] < -90 :
            angle = 180 + theta[key]
            t.set_ha('right')
        else:
            angle = theta[key]
            t.set_ha('left')
        t.set_va('center')
        t.set_rotation(angle)
        t.set_rotation_mode('anchor')


plt.box(False)
a=3
plt.xlim(-a,a)
plt.ylim(-a,a);

# %% [markdown]
# # stats

# %%
all_clues = [cl['content'] for _, game in experiment['games'].items() for _, cl in game['clues'].items()]
clue_counts = pd.value_counts(all_clues)
print("There are a total of %i unique clues in the experiment" % len(clue_counts))
# Out:
# There are a total of 3108 unique clues in the experiment

# %%
plt.figure(figsize=(12,4))
plt.hist(clue_counts.values, bins=range(describe['replications']))
plt.xlabel('Number of games that each clue participates in')
plt.ylabel('Number of clues in the bin');

# %%
# check that the average length of clues is comparable between treatment and control
t_length_list = []
c_length_list = []
for game_id, game in experiment['games'].items():
    for clue_id, clue in game['clues'].items():
        if clue_id.startswith('t'):
            t_length_list.append(len(clue['content']))
        elif clue_id.startswith('c'):
            c_length_list.append(len(clue['content']))
        else:
            assert False
            
plt.hist(t_length_list, alpha=0.5, label='Treatment', bins=range(10,100,5))
plt.hist(c_length_list, alpha=0.5, label='Control', bins=range(10,100,5))
plt.xlim(0,95)
plt.xlabel('Number of Characters')
plt.ylabel('Number of clues')
plt.title('T mean: %.02f, C mean: %.02f'%(mean(t_length_list), mean(c_length_list)));
